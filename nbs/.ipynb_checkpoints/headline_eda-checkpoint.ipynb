# %% [markdown]
# # BuzzFeed Headline Exploratory Data Analysis
#
# In this notebook we're going to explore what exactly makes a BuzzFeed headline and the tricks they use to grab your attention.

# %%
import pandas as pd
import numpy as np
import matplotlib
import re
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# matplotlib.style.use('fivethirtyeight')
sns.set_style('ticks')
plt.rcParams['font.family'] = 'monospace'
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

colors = ['#006ba6', '#0496ff', '#ffbc42', '#d81159', '#8f2d56', '#41ead4', '#ff206e']
sns.color_palette(colors)
sns.set_palette(colors)

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from langdetect import detect
from wordcloud import WordCloud
import gensim
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

stop_words = stopwords.words('english')

# %config InlineBackend.figure_format = 'retina'
pd.set_option("display.max_rows", None)


print('Setup Complete.')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jordansamek/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jordansamek/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages/sklearn/decomposition/_lda.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# Setup Complete.
# /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages/matplotlib_inline/config.py:75: DeprecationWarning: InlineBackend._figure_format_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_format_changed(self, name, old, new):

# %%
data = pd.read_csv('../data/buzzfeed_headlines.csv')
print(data.shape)

# let's shuffle the dataset so everything is mixed together appropriately

data = data.sample(frac=1).reset_index().drop('index', axis=1)
data.head()
# Out:
# (380, 3)
#                                              content  \
# 0  If you watch closely, you can see Abed deliver...
# 1  Daniel Zuchnik / GC Images\r\n"A boy named Jac...
# 2                       Let's learn more about love!
# 3  Getty Images / Universal / Everett Collection\...
# 4  Frazer Harrison / Getty Images for ELLE\r\n"I ...
#
#                                          description  \
# 0  If you watch closely, you can see Abed deliver...
# 1  "It's a journey, and it's never-ending."View E...
# 2     Let's learn more about love!View Entire Post ›
# 3  Patiently waiting for my significant other to ...
# 4  "They can tell me if they want to be part of m...
#
#                                                title
# 0  71 Brilliant Details From "Community" That Sho...
# 1  Kelsea Ballerini Shared Her Struggle With Buli...
# 2  People Who Practice Polyamory — Do You Have Ru...
# 3  21 Celebrities Who Appeared In Their Significa...
# 4  Mindy Kaling Wants Her Kids' "Consent" Before ...

# %% [markdown]
# ## Exploring our Text Analytics

# %% [markdown]
# For simpler pre-processing, we'll convert the `title` column text into lowercase first.

# %%
def lower_title(text):
    text = str(text).lower()
    return text

data['title'] = data['title'].apply(lower_title)

data.head()
# Out:
#                                              content  \
# 0  If you watch closely, you can see Abed deliver...
# 1  Daniel Zuchnik / GC Images\r\n"A boy named Jac...
# 2                       Let's learn more about love!
# 3  Getty Images / Universal / Everett Collection\...
# 4  Frazer Harrison / Getty Images for ELLE\r\n"I ...
#
#                                          description  \
# 0  If you watch closely, you can see Abed deliver...
# 1  "It's a journey, and it's never-ending."View E...
# 2     Let's learn more about love!View Entire Post ›
# 3  Patiently waiting for my significant other to ...
# 4  "They can tell me if they want to be part of m...
#
#                                                title
# 0  71 brilliant details from "community" that sho...
# 1  kelsea ballerini shared her struggle with buli...
# 2  people who practice polyamory — do you have ru...
# 3  21 celebrities who appeared in their significa...
# 4  mindy kaling wants her kids' "consent" before ...

# %% [markdown]
# Let's see how long each title is, on a character-based level, and maybe what the average title length is:

# %%
data['title_len'] = data['title'].apply(len)
data.sample(4)
# Out:
#                                                content  \
# 188  Erika Goldring / WireImage / Getty Images\r\nA...
# 219  "Why do people keep putting non-skincare produ...
# 163  Randy Holmes / ABC via Getty Images\r\nOR we c...
# 361  RCA / Columbia\r\nBefore Olivia Rodrigo arrive...
#
#                                            description  \
# 188              Take notes, Travis.View Entire Post ›
# 219  "Why do people keep putting non-skincare produ...
# 163         I stan a pragmatic king.View Entire Post ›
# 361  Yes, "Tik Tok" by Ke$ha is on the list.View En...
#
#                                                  title  title_len
# 188  17 times musicians were decent human beings an...         98
# 219  teens are using lube as primer, so i talked to...        124
# 163  tom hanks declined jeff bezos' space flight of...        109
# 361  19 songs that would be tiktok famous if they w...         64

# %%
data['title_len'].describe()
# Out:
# count    380.000000
# mean      87.871053
# std       24.656836
# min       31.000000
# 25%       69.000000
# 50%       86.000000
# 75%      104.000000
# max      160.000000
# Name: title_len, dtype: float64

# %% [markdown]
# Taking a look at what each title's length looks like, starting from the minimum length to the max.

# %%
data.groupby(['title_len'], as_index=False)['title'].max()
# Out:
#      title_len                                              title
# 0           31                    【速報】hpvワクチン、積極的勧奨の再開を了承　厚労省の審議会
# 1           35                what's your nightmare period story?
# 2           38             トランスジェンダーは婦人科を受診しちゃいけないの？　当事者や医師に聞いてみた
# 3           39            how would you die on "game of thrones?"
# 4           42         these random questions reveal if you floss
# 5           43        自民党「影の幹事長」がdappiへの関与を否定。群馬の村で見えた“親族のつながり“とは
# 6           47    17 actors who i'm convinced could play any role
# 7           48   rate these creamy foods and we'll guess your age
# 8           49  36 products that might help solve your sleep woes
# 9           50  these 90s rom-coms will 100% make your life be...
# 10          51  these 20 high fashion dogs dress better than y...
# 11          52  what’s it like to have never been in a relatio...
# 12          53  the 50 best "parks and recreation" quotes of a...
# 13          54  what are some misconceptions about open relati...
# 14          55  what do you do when your identical twin starts...
# 15          56  top 5 digital marketing strategies that worked...
# 16          57  these 18 posts are straight out of an alternat...
# 17          58  your zodiac sign will reveal the next book you...
# 18          59  your answers will predict which horror icon wi...
# 19          60  jojo siwa and kylie prew reportedly broke up "...
# 20          61  there's a "twin peaks" resident in us all, whi...
# 21          62  34 cleaning products that get the job done the...
# 22          63  kelsea ballerini shared her struggle with buli...
# 23          64  30 things '90s kids did all the time that make...
# 24          65  the data is out — this is what parents named t...
# 25          66  will ferrell says he turned down $29 million t...
# 26          67  the movie songs you know and don't are a total...
# 27          68  45 american holidays that we should absolutely...
# 28          69  your answers will determine which "halloween k...
# 29          70  the film "passing" is here and this is where y...
# 30          71  this language quiz will reveal whether you're ...
# 31          72  only the "rich friend" grew up with 16/36 of t...
# 32          73  these 20 common business practices are quite u...
# 33          74  if your closet is a disaster zone, these 34 or...
# 34          75  woodworkers don't get the credit they deserve,...
# 35          76  think you can decipher these countries by desc...
# 36          77  noodle the pug has the internet by a chokehold...
# 37          78  this basic bone test will expose you if you sk...
# 38          79  wanna know your dominant personality trait? ju...
# 39          80  if you love "ratatouille," seeing these 17 dis...
# 40          81  halle berry approved of saweetie's "catwoman" ...
# 41          82  we'll tell you your soulmate's initial based o...
# 42          83  those "evil be like memes" are taking over twi...
# 43          84  kim kardashian poked fun at her three divorces...
# 44          85  tell us some popular movie costars who didn't ...
# 45          86  jamie lee curtis explained why #metoo would ha...
# 46          87  these 15 celebrities use stage names, and only...
# 47          88  rihanna perfectly replicated an instagram post...
# 48          89  timothée chalamet used to have a youtube chann...
# 49          90  meghan trainor spilled on her biggest parentin...
# 50          91  zendaya wore a bold gold breastplate on the re...
# 51          92  wonho read the internet's thirstiest tweets ab...
# 52          93  kristen bell revealed that dax shepard once he...
# 53          94  salma hayek told a hilarious story about angel...
# 54          95  tell us your witch opinions and we'll reveal w...
# 55          96  women are sharing how young they were when the...
# 56          97  these are the trendiest foods from the past ye...
# 57          98  two months ago, i switched one thing in my ski...
# 58          99  megan fox full-on straddled machine gun kelly ...
# 59         100  women are pointing out female issues that don'...
# 60         101  most people have tried 7/26 of these sweet, so...
# 61         102  sure, you've probably tried 13/40 of these cho...
# 62         103  women are sharing their creepiest "nice guy" s...
# 63         104  the good, the bad, and the ugly celebrity hall...
# 64         105  people have many thoughts and critiques about ...
# 65         106  teachers are revealing the worst things studen...
# 66         107  these 16 iconic characters wouldn't be the sam...
# 67         108  nicole kidman is unveiled as lucille ball in t...
# 68         109  tom holland shared another tribute to zendaya ...
# 69         110  chances are, your birth control comes with a l...
# 70         111  “the size of your body is the least interestin...
# 71         112  salma hayek and lauren ridloff say that marvel...
# 72         114  these 35 bad parents have zero excuses for the...
# 73         115  these 17 tv and movie moments are taken straig...
# 74         116  spiritual abuse survivors are sharing their st...
# 75         117  24 celeb siblings where we can't even think of...
# 76         118  a latina character has just been dropped from ...
# 77         119  people are calling out the celebrities they su...
# 78         120  dakota johnson says that her grandmother tippy...
# 79         121  dwayne "the rock" johnson wants to be daniel c...
# 80         123  "succession" star sarah snook secretly got mar...
# 81         124  thanksgiving chocolate truffles, 'everything b...
# 82         125  women on tiktok are thanking this mom for educ...
# 83         126  gigi hadid and zayn malik have reportedly spli...
# 84         128  princess mako of japan gave up her royal title...
# 85         129  12 celeb engagement rings that must have taken...
# 86         130  dakota johnson was asked about the allegations...
# 87         131  people are saying changing your voicemail coul...
# 88         133  billy porter called out vogue for featuring ha...
# 89         137  florence pugh just explained why more of us sh...
# 90         140  more details are coming out about the british ...
# 91         142  matthew mcconaughey clarified his stance on va...
# 92         143  this person is going viral for roasting people...
# 93         144  travis barker's son posted this tiktok from hi...
# 94         145  netflix have announced who they've cast for un...
# 95         146  twitter is currently predicting scott disick's...
# 96         149  dakota johnson reflected on how "fifty shades ...
# 97         150  scott disick had lunch with kris jenner while ...
# 98         151  t.j. osborne celebrated his win at the cmas by...
# 99         152  as a "got" fan, i was not well when i realized...
# 100        160  zendaya and tom holland's adorable instagram i...

# %% [markdown]
# We should probably remove the 3 titles that aren't English, just for the sake of consistency of our values that we'll eventually be processing and putting into our ML model.

# %%
def detect_lang(txt):
    try:
        return detect(txt)
    except:
        return np.nan
    
data['language'] = data.title.apply(detect_lang)

# %%
data = data[data.language == "en"]
data.groupby(['title_len'], as_index=False)['title'].max()
# Out:
#     title_len                                              title
# 0          35                what's your nightmare period story?
# 1          38             just 34 very nice things for your home
# 2          39            how would you die on "game of thrones?"
# 3          42         these random questions reveal if you floss
# 4          47    17 actors who i'm convinced could play any role
# 5          48   rate these creamy foods and we'll guess your age
# 6          49  36 products that might help solve your sleep woes
# 7          50  these 90s rom-coms will 100% make your life be...
# 8          51  these 20 high fashion dogs dress better than y...
# 9          52  what’s it like to have never been in a relatio...
# 10         53  the 50 best "parks and recreation" quotes of a...
# 11         54  what are some misconceptions about open relati...
# 12         55  what do you do when your identical twin starts...
# 13         56  top 5 digital marketing strategies that worked...
# 14         57  these 18 posts are straight out of an alternat...
# 15         58  your zodiac sign will reveal the next book you...
# 16         59  your answers will predict which horror icon wi...
# 17         60  jojo siwa and kylie prew reportedly broke up "...
# 18         61  there's a "twin peaks" resident in us all, whi...
# 19         62  34 cleaning products that get the job done the...
# 20         63  kelsea ballerini shared her struggle with buli...
# 21         64  30 things '90s kids did all the time that make...
# 22         65  the data is out — this is what parents named t...
# 23         66  will ferrell says he turned down $29 million t...
# 24         67  the movie songs you know and don't are a total...
# 25         68  45 american holidays that we should absolutely...
# 26         69  your answers will determine which "halloween k...
# 27         70  the film "passing" is here and this is where y...
# 28         71  this language quiz will reveal whether you're ...
# 29         72  only the "rich friend" grew up with 16/36 of t...
# 30         73  these 20 common business practices are quite u...
# 31         74  if your closet is a disaster zone, these 34 or...
# 32         75  woodworkers don't get the credit they deserve,...
# 33         76  think you can decipher these countries by desc...
# 34         77  noodle the pug has the internet by a chokehold...
# 35         78  this basic bone test will expose you if you sk...
# 36         79  wanna know your dominant personality trait? ju...
# 37         80  if you love "ratatouille," seeing these 17 dis...
# 38         81  halle berry approved of saweetie's "catwoman" ...
# 39         82  we'll tell you your soulmate's initial based o...
# 40         83  those "evil be like memes" are taking over twi...
# 41         84  kim kardashian poked fun at her three divorces...
# 42         85  tell us some popular movie costars who didn't ...
# 43         86  jamie lee curtis explained why #metoo would ha...
# 44         87  these 15 celebrities use stage names, and only...
# 45         88  rihanna perfectly replicated an instagram post...
# 46         89  timothée chalamet used to have a youtube chann...
# 47         90  meghan trainor spilled on her biggest parentin...
# 48         91  zendaya wore a bold gold breastplate on the re...
# 49         92  wonho read the internet's thirstiest tweets ab...
# 50         93  kristen bell revealed that dax shepard once he...
# 51         94  salma hayek told a hilarious story about angel...
# 52         95  tell us your witch opinions and we'll reveal w...
# 53         96  women are sharing how young they were when the...
# 54         97  these are the trendiest foods from the past ye...
# 55         98  two months ago, i switched one thing in my ski...
# 56         99  megan fox full-on straddled machine gun kelly ...
# 57        100  women are pointing out female issues that don'...
# 58        101  most people have tried 7/26 of these sweet, so...
# 59        102  sure, you've probably tried 13/40 of these cho...
# 60        103  women are sharing their creepiest "nice guy" s...
# 61        104  the good, the bad, and the ugly celebrity hall...
# 62        105  people have many thoughts and critiques about ...
# 63        106  teachers are revealing the worst things studen...
# 64        107  these 16 iconic characters wouldn't be the sam...
# 65        108  nicole kidman is unveiled as lucille ball in t...
# 66        109  tom holland shared another tribute to zendaya ...
# 67        110  chances are, your birth control comes with a l...
# 68        111  “the size of your body is the least interestin...
# 69        112  salma hayek and lauren ridloff say that marvel...
# 70        114  these 35 bad parents have zero excuses for the...
# 71        115  these 17 tv and movie moments are taken straig...
# 72        116  spiritual abuse survivors are sharing their st...
# 73        117  24 celeb siblings where we can't even think of...
# 74        118  a latina character has just been dropped from ...
# 75        119  people are calling out the celebrities they su...
# 76        120  dakota johnson says that her grandmother tippy...
# 77        121  dwayne "the rock" johnson wants to be daniel c...
# 78        123  "succession" star sarah snook secretly got mar...
# 79        124  thanksgiving chocolate truffles, 'everything b...
# 80        125  women on tiktok are thanking this mom for educ...
# 81        126  gigi hadid and zayn malik have reportedly spli...
# 82        128  princess mako of japan gave up her royal title...
# 83        129  12 celeb engagement rings that must have taken...
# 84        130  dakota johnson was asked about the allegations...
# 85        131  people are saying changing your voicemail coul...
# 86        133  billy porter called out vogue for featuring ha...
# 87        137  florence pugh just explained why more of us sh...
# 88        140  more details are coming out about the british ...
# 89        142  matthew mcconaughey clarified his stance on va...
# 90        143  this person is going viral for roasting people...
# 91        144  travis barker's son posted this tiktok from hi...
# 92        145  netflix have announced who they've cast for un...
# 93        146  twitter is currently predicting scott disick's...
# 94        149  dakota johnson reflected on how "fifty shades ...
# 95        150  scott disick had lunch with kris jenner while ...
# 96        151  t.j. osborne celebrated his win at the cmas by...
# 97        152  as a "got" fan, i was not well when i realized...
# 98        160  zendaya and tom holland's adorable instagram i...

# %%
data = data.drop('language', axis=1)

# %%
data.head()
# Out:
#                                              content  \
# 0  If you watch closely, you can see Abed deliver...
# 1  Daniel Zuchnik / GC Images\r\n"A boy named Jac...
# 2                       Let's learn more about love!
# 3  Getty Images / Universal / Everett Collection\...
# 4  Frazer Harrison / Getty Images for ELLE\r\n"I ...
#
#                                          description  \
# 0  If you watch closely, you can see Abed deliver...
# 1  "It's a journey, and it's never-ending."View E...
# 2     Let's learn more about love!View Entire Post ›
# 3  Patiently waiting for my significant other to ...
# 4  "They can tell me if they want to be part of m...
#
#                                                title  title_len
# 0  71 brilliant details from "community" that sho...        114
# 1  kelsea ballerini shared her struggle with buli...         63
# 2  people who practice polyamory — do you have ru...         88
# 3  21 celebrities who appeared in their significa...         76
# 4  mindy kaling wants her kids' "consent" before ...         82

# %% [markdown]
# Before cleaning our `title` column to be put into an ML pipeline, let's just do some basic text analytics to get a sense of what each title consists of.

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 8))

plt.subplot(1, 2, 1)
sns.distplot(data['title_len']).set_title('Distribution of Title Lengths', fontsize=20, fontweight='bold')
plt.axvline(np.array(data['title_len'].mean()), ls='dashed')
plt.annotate(round(data['title_len'].mean(),2), xy=(90, 0.0165), xycoords='data', xytext=(110, 0.0164),
             arrowprops=dict(facecolor='blue', shrink=0.05))


title_word_len = data['title'].str.split().map(lambda x: len(x))
word_len_mean = round(title_word_len.mean(), 2)

plt.subplot(1, 2, 2)
sns.distplot(title_word_len).set_title('Distribution of Word Lengths', fontsize=20, fontweight='bold')
plt.axvline(word_len_mean, ls='dashed')
plt.annotate(word_len_mean, xy=(15.7, 0.095), xycoords='data', xytext=(20, 0.094),
             arrowprops=dict(facecolor='blue', shrink=0.05))
plt.xlabel("Number of words in title")

# ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
# ax.set_ylabel('')

plt.tight_layout()
plt.show();

# %%
min_title_words = data.title.str.split().map(lambda x: len(x)).min()
max_title_words = data.title.str.split().map(lambda x: len(x)).max()

print(f"The minimum amount of words in our titles is {min_title_words}")
print(f"The maxmimu amount of words in our titles is {max_title_words}")
# Out:
# The minimum amount of words in our titles is 5
# The maxmimu amount of words in our titles is 29

# %% [markdown]
# If anyone has ever seen any sort of clickbait headlines (which BuzzFeed apparently denies their headlines are clickbait), they've most likely noticed it probably has an odd number thrown in there like "27 Things You Shouldn't Do on a First Date!!" to grab your attention. This type of headline works in many different ways, but one major way is because we humans love lists, especially numbered lists. So let's check out how many headlines of BuzzFeed's contain numbers in them:

# %%
num_in_headline_count = 0
no_num_headline_count = 0
for line in data.title:
    if bool(re.search('\d+', line)) == True:
        num_in_headline_count += 1
    else:
        no_num_headline_count += 1
# Out:
# <>:4: DeprecationWarning: invalid escape sequence \d
# <>:4: DeprecationWarning: invalid escape sequence \d
# <>:4: DeprecationWarning: invalid escape sequence \d
# /var/folders/xs/d1td623j4l5_3s9p262jr4yw0000gn/T/ipykernel_5633/526895669.py:4: DeprecationWarning: invalid escape sequence \d
#   if bool(re.search('\d+', line)) == True:

# %%
# Headlines with numbers - {num_in_headline_count}
# Headlines without numbers - {no_num_headline_count}
num_in_headline_count, no_num_headline_count
# Out:
# (178, 197)

# %%
headline_nums = {'num_in_headline_count': num_in_headline_count, 'no_num_headline_count': no_num_headline_count}
headline_numbers = pd.DataFrame(headline_nums, index=[0])

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=headline_numbers, ax=ax, alpha=0.8, zorder=2, palette=colors[-2:], edgecolor='black')
ax.set_title("# of Headlines with & without numbers in them", fontweight='bold', fontsize=20)
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
ax.set_xlabel("Numbers in Headlines", fontweight='bold', fontsize=15)
ax.set_ylabel("Count", fontweight='bold', fontsize=15)
plt.tight_layout()
plt.show();

# %% [markdown]
# My guess would have been that there were more headlines with numbers in them than without, but as we can see the headlines are relatively balanced when it comes to titles containing numbers. Even more surprisingly, headlines without numbers have the slight edge over headlines that include digits.

# %% [markdown]
# For simplicity sake, let's cut down our data so that it just includes our title text and our text length. We can come back later and do some analysis on the `content` and `description` features of our original dataset, but for now it will be easier to just work with our necessary features.

# %%
title_df = data[['title', 'title_len']]
title_df.sample(5)
# Out:
#                                                  title  title_len
# 323  if you love "ratatouille," seeing these 17 dis...         80
# 24   20 wild, lavish, or weirdly specific things ri...         98
# 31   17 of the best toys and gifts from indigo for ...         66
# 251  these 17 tv and movie moments are taken straig...        115
# 297  in the wake of "the great resignation", aussie...         89

# %% [markdown]
# Remove stopwords from the titles and then we'll make a quick wordcloud to visualize popular words before we fully clean the text for other NLP analysis.

# %%
title_df['clean_title'] = title_df['title'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# %%
title_df.sample(5)
# Out:
#                                                  title  title_len  \
# 255  dakota johnson says that her grandmother tippy...        120
# 161  film and tv crews, we want to hear about the w...         70
# 182  more details are coming out about the british ...        140
# 9    i simply don't understand why more people aren...         69
# 228  kanye west stepped out in venice with an alien...        125
#
#                                            clean_title
# 255  dakota johnson says grandmother tippy hedren's...
# 161    film tv crews, want hear working conditions set
# 182  details coming british baker caught using ille...
# 9        simply understand people watching "dickinson"
# 228  kanye west stepped venice alien-like mask face...

# %%
clean_title_vals = title_df['clean_title'].values
print(str(clean_title_vals))
# Out:
# ['71 brilliant details "community" emmy "best attention detail comedy series"'
#  'kelsea ballerini shared struggle bulimia teenager'
#  'people practice polyamory — rules put place relationships?'
#  "21 celebrities appeared significant other's movies tv shows"
#  'mindy kaling wants kids\' "consent" sharing pics social media'
#  'basic bone test expose skipped high school anatomy'
#  "thanksgiving chocolate truffles, 'everything leftovers' seasoning, 50+ holiday trader joe's products try asap"
#  'think decipher countries descriptions residents?'
#  'these19 mind-blowing easter eggs stephen king adaptations show deep things connect'
#  'simply understand people watching "dickinson"'
#  '17 haunted houses people periods would actually scared'
#  '13 tweets awe appreciation kristen stewart\'s princess diana "spencer"'
#  'people poor students rich schools shared experiences, child feel like'
#  'native american chief, anne frank, 15 costumes absolutely steer clear halloween'
#  '20 sci-fi novel adaptations even better book'
#  'there\'s "twin peaks" resident us all, one you?'
#  "female ride-share driver, we'd like hear experiences"
#  'people look things women like them, honestly messed'
#  '17 "dune" "star wars" similarities sci-fi fans instantly recognize'
#  '38 shocking photos iconic places vs. planet warms 3 degrees celsius'
#  'heard 15/18 underrated gems bts true army!'
#  'chance rapper said he\'s experienced "a lot dark days" dealing ptsd'
#  'answers predict horror icon murder'
#  'took pug "most dog-friendly" hotel us, collective thoughts'
#  '20 wild, lavish, weirdly specific things rich bosses asked employees get'
#  'chocolate milk comes brown cows, 26 ridiculous conclusions kids came based flimsy evidence'
#  "tried kraft's new mac & cheese flavors and, wow, yes, sign"
#  'princess mako japan gave royal title marry "commoner" fiancé, kei komuro, story deserves movie asap'
#  "women sharing young first catcalled, i'm disgusted men"
#  'people calling celebrities suspect faking personalities camera, fascinating'
#  'noodle pug internet chokehold “no bones day” content'
#  '17 best toys gifts indigo kid life'
#  '26 things people said children mind-blowing, astonishing, 100% fake'
#  '14 people told us student loan debt would change lives, important conversation'
#  'aussies trolling americans completely missing brief mullet'
#  'sure, probably tried 13/40 chocolate foods, highly doubt tried 27/40'
#  'hello, saw "dune" officially timothée chalamet hot bandwagon'
#  "endless scooby-doo impression, detour ex's house, 23 ways men absolutely ruined first dates"
#  "wonho read internet's thirstiest tweets gave us peek abs"
#  'really know famous people recognize celebrities walked street'
#  'kim kardashian poked fun three divorces (and weddings) wedding toast'
#  'men sharing annoying thing guy, answers honestly place'
#  'matthew mcconaughey clarified stance vaccinating children covid-19, previously suggesting kids get shot'
#  '12 celeb engagement rings must taken money world purchase 8 affordable side'
#  '34 hysterical tweets month far need see'
#  'zendaya wore bold gold breastplate red carpet, cannot stop thinking'
#  'two months ago, switched one thing skincare routine — skin never looked glowier'
#  'nicole kidman unveiled lucille ball "being ricardos" teaser trailer, wow, nailed'
#  'harry sally? john mclaine holly? quiz determine iconic holiday couple'
#  '51 film tv scenes sexy heck without ounce sex'
#  'again, nick cannon plotting kids — time saweetie'
#  'lauren ridloff made history becoming first deaf actor play marvel superhero'
#  '28 men politely turned nerve keep harassing someone'
#  'became first latinx woman disability mt. kilimanjaro, proving "there nothing disabled person can\'t do"'
#  '17 historical events people taught school, definitely know'
#  'gwyneth paltrow revealed talks kids sex informative af'
#  'taylor swift dressed squirrel halloween 2021 something nutty say'
#  "people many thoughts critiques kendall jenner wearing dress someone else's wedding"
#  'adele talked body objectified response following viral birthday photo'
#  'jamie lee curtis explained #metoo would "really upset" mother janet leigh'
#  '22 self-care products parents want treat'
#  '21 things publix workers absolutely hate 4 things absolutely love'
#  'carole baskin "tiger king" revealed thinks happened missing husband reddit ama'
#  "used kneeling ergonomic chair 30 days here's need know"
#  'ed sheeran says thought gay "for bit" kid'
#  '11 boyfriends epitome laziness, 11 boyfriends epitome caring'
#  '30 products prove miracles happen believe'
#  'jessica chastain revealed conditions "scenes marriage" nude scenes oscar isaac'
#  'adele revealed new album includes voicemail left friend experiencing anxiety attack divorce'
#  '"got" fan, well realized "eternals" premiere brought richard madden kit harrington place time'
#  'wanna know dominant personality trait? eat ice cream find'
#  "tell us usual mcdonald's order we'll guess introvert extrovert"
#  'k-pop girl group twice answered 30 rapid fire questions learned much'
#  '14 haunting real-life facts ever heard'
#  'marvel working kathryn hahn "wandavision" spinoff series, yes, greatest day ever'
#  'good luck making 75 terrifying things childhood millennial'
#  "halloween, scariest thing might results week's pop culture quiz"
#  '15 "influencers" absolutely zero respect sellers businesses reached'
#  '34 nice things home'
#  'kristen bell revealed dax shepard helped mouth breastfeeding'
#  'home chef’s latest deal served: $110 first five orders'
#  'australians explaining "bogan" rest world i\'m cackling'
#  '19 adorable instagram posts make love zendaya even'
#  '50 tweets thoroughly shit australian lifestyle'
#  '21 famous men seriously deserve sexiest man alive because...well, pictures speak themselves, folks'
#  "23 hysterically weird things people saw friends' houses friends thought normal"
#  '48 problem-solving products make "i\'ll later" list way easier'
#  '34 products give second glance'
#  'let\'s rank wildest moments "you" season 3 ton'
#  '14 thanksgiving fails even wish upon worst enemy'
#  '45 american holidays absolutely get day'
#  'women tiktok thanking mom educating different shades breast milk — see doctor'
#  'emma watson looked like actual angel making return red carpet'
#  '16 books black authors total must reads'
#  'tbh, 30 red carpet looks would make pretty incredible halloween costumes'
#  'treated differently work disability?'
#  'closet disaster zone, 34 organization products help'
#  '19 things lesbians sick tired straight people'
#  'adele says doesn’t want major tour behind “30” people might reminded covid-19 listen music'
#  '21 "eternals" red carpet moments prove cast ready take marvel cinematic universe'
#  '23 pictures abandoned places australia creep tf'
#  '"romy michele" musical star says fired pregnant right show supposed hit broadway'
#  "17 disney moments heartbreakingly real, i'm sure forgot making kids' films"
#  "buy 30 reviewer-loved products already, maybe i'll stop including many posts"
#  'salma hayek lauren ridloff say marvel went extreme lengths maintain secrecy around "eternals"'
#  '16 college dorm horror stories prove never become ra'
#  'people sharing random bits life advice wholesome'
#  'people sharing paranormal thing ever happened them, reading can’t sleep'
#  'questions "squid game" season two need answer?'
#  'tell favorite foreign film netflix' 'here\'s seen cast "hawkeye"'
#  "tell us witch opinions we'll reveal mystical witchy read pick next"
#  '36 products might help solve sleep woes'
#  'australians sharing favourite phrases make non-aussies say "what?" hilarious'
#  'australian women sharing stories approached men public places making blood boil'
#  'order school lunch find old mentally'
#  '15 things entitled customers signal servers tip well, annoying terrible'
#  '17 things seated restaurant, host judging hard'
#  'amanda seyfried says "tough case covid" right getting oscar nomination "mank"'
#  'random questions reveal floss'
#  "dax shephard got real like unclog kristen bell's clogged milk duct breastfeeding"
#  'film "passing" seen cast'
#  '28 serial killer facts true crime fans find shocking'
#  'turns actually "coregasm" ab exercises, excuse million crunches'
#  "40 pettiest signs i've seen goddamn life"
#  '36 unusual pet friendships could break internet'
#  'top 5 digital marketing strategies worked tesla'
#  "no, shoving garlic nose clear sinuses — here's learned medical tiktok"
#  '37 "australians like" tweets make laugh, say "saur troo"'
#  "we'll tell soulmate's initial based preference instant noodles"
#  'treated differently work disability?'
#  'director "queen damned" says cher almost cast instead aaliyah'
#  "17 actors i'm convinced could play role"
#  'binging "cowboy bebop" episode rankings came'
#  '17 delivery driver horror stories make want tip extra next time order something'
#  'movie songs know total giveaway age' 'what’s like never relationship?'
#  'people included dogs weddings sweetest ways'
#  'rihanna perfectly replicated instagram post gunna halloween 2021 costume'
#  '55 awkward kinda awful early 2000s trends poised make comeback whether like'
#  'tefi pessoa joked wearing dress incorrectly uk premiere "dune"'
#  "zendaya tom holland's adorable instagram interaction sending frenzy, imagine i'll react they're actually red carpet together"
#  '21 bizarre "secret life american teenager" moments prove none us allowed watch high school'
#  'jamie foxx said plan getting married anytime soon'
#  '20 high fashion dogs dress better'
#  'amazon canada releasing epic daily deals month feels like black friday came early'
#  'hugh jackman showed fans accidentally "sliced" nose practicing "the music man"'
#  'attention non-meat eaters — finally get impossible burgers australia'
#  '19 horrible parent-teacher interactions prove teachers get paid enough'
#  '18 famous people flipped script completely changed career paths'
#  'meghan trainor spilled biggest parenting fail super easy mistake make'
#  'people tried "fix" someone relationship, want hear story'
#  "twitter currently predicting scott disick's reaction kourtney kardashian travis barker engagement news, i'm ngl, they're spot"
#  '50 scammers got exactly deserved end'
#  'eve shared photo baby bump announced pregnant first baby'
#  'dakota johnson reflected "fifty shades grey" "pigeonhole" career, days costar jamie dornan said done "no harm"'
#  "people sharing wholesome moments they've ever stranger, stories make day"
#  'khloé kardashian said true wants dress "pua pig" might'
#  '"evil like memes" taking twitter, 18 best ones'
#  'film tv crews, want hear working conditions set'
#  'language quiz reveal whether australia usa'
#  "tom hanks declined jeff bezos' space flight offer, reason make love tom hanks much"
#  '24 celebrity couples mega famous, people know dated'
#  '32 things care love wine'
#  '35 products stop putting buzzfeed shopping posts, simply deserve'
#  '19 "squid game" behind-the-scenes facts super interesting'
#  'misconceptions open relationships?'
#  '35 forgotten songs unlock memories aussie millennials'
#  'breakfast questions predict chance crush'
#  '"you" season 3 dropped everyone thirsting theo engler'
#  '18 posts straight alternate dimension' 'film "passing" seen cast'
#  '16 people job interviews bad, literally walked'
#  '28 powerful cleaning products that’ll make easier keep home tip-top shape'
#  '45 everyday things thought way cheaper actually buy'
#  '27 cleaning products reviewers swear "only thing worked"'
#  '29 actors effed big time shared major spoilers movies tv shows'
#  'taylor swift pete davidson sang "three sad virgins" last night\'s "snl"'
#  "angelina jolie's kids grown yes, old"
#  '21 celebrity couples made marriages work 20 years 15 make first year'
#  "details coming british baker caught using illegal american sprinkles, can't stop laughing entire saga"
#  '90s rom-coms 100% make life better'
#  "here's australians react spot kangaroo front yard"
#  "identify beloved tv characters we'll reveal whether hail usa australia"
#  "what's nightmare period story?"
#  "35 bad parents zero excuses toxic things they've said done children years"
#  '17 times musicians decent human beings actually stopped shows protect fans'
#  'skeet ulrich admitted know "scream" comedy started shooting'
#  'hailey bieber says "extremely difficult" dealing justin bieber\'s sobriety journey'
#  '"eternals" introduced new character mid-credits scene — here\'s we\'re freaking'
#  'many macabre movies watched lifetime?'
#  'ariana grande\'s "miss creature" homage "black lagoon" proves reigning halloween queen'
#  '12 times celebs called celebs 2021 far'
#  '21 hilarious bumper stickers guaranteed spice back minivan'
#  "23 dylan o'brien moments prove he's amazing screen"
#  'shia labeouf almost cast "call name" instead armie hammer'
#  '17 times celebrities tore every single rule book red carpet'
#  'well remember opening monologue "the lord rings: fellowship ring"?'
#  'here\'s seen cast "locke & key"'
#  'unequal pay, unfulfillment, 17 reasons women leaving jobs tech'
#  '24 roles actors literally embarrassed performance'
#  'billy porter called vogue featuring harry styles dresses skirts, nonbinary style "changed whole game"'
#  'taylor swift performed "all well" "snl" last night front lot famous friends'
#  'women sharing creepiest "nice guy" stories, need every man dates women read'
#  '14 times detective rosa diaz "brooklyn nine-nine" bisexual legend'
#  'reese witherspoon says "legally blonde" rejected filming stanford university'
#  '16 husbands whose hysterical fails left very, embarrassed'
#  'would die "game thrones?"'
#  '24 products make say "i understand buzzfeed always writes these"'
#  'jamie lee curtis revealed lindsay lohan secret text code identify other, suddenly feeling like 2003'
#  'identical twin starts camming?'
#  'david duchovny hilariously recalled brutal "full house" audition led nowhere'
#  'jojo siwa kylie prew reportedly broke "two weeks ago"'
#  'watched enough tv tell tv shows spinoffs?'
#  'lily collins defended "emily paris" acknowledged emily seems "annoying"'
#  'zodiac sign reveal next book read'
#  "teens using lube primer, talked dermatologist – spoiler alert – it'll clog pores give acne"
#  'famous voices behind characters "big mouth"'
#  "dolly parton shared rare photo hot husband carl dean, suddenly i'm jolene take man"
#  'salma hayek told hilarious story angelina jolie slamming face birthday cake'
#  '14 things never ever want swallow unless trying go er'
#  'person going viral roasting people visit popular cities, funny follow someone social media like'
#  'data — parents named babies 2021'
#  '36 beauty products results inspire shake normal routine'
#  'true "friends" fans remember little details – one them?'
#  "kanye west stepped venice alien-like mask face, guess good mine what's going"
#  '15 celebrity couples unexpected still keep night'
#  '17 people already halloween year'
#  "scott disick lunch kris jenner filming kardashians' new reality show, amid reported drama kourtney kardashian's engagement"
#  '27 deeply unsettling pictures make say, "wow, genuinely wish seen that"'
#  'miles teller said he\'s vaccinated covid-19 "a while" taylor swift fans questioned vax status'
#  'stairs lead nowhere, 17 photos sit right'
#  'a$ap rocky stopped show demanded fallen fans picked resurfaced video'
#  '50 funniest quotes "what shadows"'
#  'latina character dropped neil patrick harris\' new netflix show "hurtful derogatory"'
#  "people sharing one food gives away from, bet can't get right"
#  'adorable pet moments warm soul forever'
#  '35 affordable things make feel oh-so-fancy'
#  "travis barker's son posted tiktok dad kourtney kardashian's engagement dinner, feels like actually there???"
#  'jodie turner-smith opened breastfeeding journey motherhood: "cheers mummas — especially black mamas"'
#  '"succession" star sarah snook secretly got married almost year ago, ceremony, thankfully, nothing like shiv\'s'
#  "i'm bit french fry aficionado, ranked fast-food fries i've ever"
#  '16 iconic characters without important input actors played'
#  'gigi hadid zayn malik reportedly split zayn issued statement regarding alleged incident yolanda hadid'
#  '18 celebrity instagrams probably missed last week'
#  '50 best "parks recreation" quotes time'
#  'name iconic horror movie slashers based one clue?'
#  'people sharing worst job interview horror stories, red flags everywhere'
#  '17 tv movie moments taken straight real life, prove truth stranger fiction'
#  '"penn badgley hot joe goldberg not" 26 great tweets describing wild "you" season 3'
#  "rate creamy foods we'll guess age"
#  'adele recalled feeling ashamed divorce simon konecki: "you feel like good job"'
#  'dakota johnson says grandmother tippy hedren\'s career "ruined" alfred hitchcock\'s alleged sexual assault'
#  '“the size body least interesting thing you” said intuitive eating dietitian tiktok'
#  '16 coolest & swankiest college campuses us'
#  'good, bad, ugly celebrity halloween costumes 10+ years ago totally forgot'
#  "put ranch 13 foods, i'm sorry, gross"
#  'try tell many celebs first trailer "don\'t look up," believe — watch'
#  '25 products disgusting-yet-satisfying photos hate love see'
#  'author "sex city" shared honest take show\'s un-feminist ending'
#  'people sharing popular "disgusting" things everyone stop doing, points made'
#  'kal penn cardi b’s wholesome twitter exchange led cardi offering officiate upcoming wedding'
#  'adele recalled feeling ashamed divorce simon konecki: "you feel like good job"'
#  'eliza dushku spoke alleged sexual harassment faced "bull" co-star michael weatherly said would "smell" set'
#  "former victoria's secret angel erin heatherton admits turned dangerous medications stay skinny"
#  'women pointing female issues get enough attention, lies detected'
#  'true fans marvel cinematic universe score 10/13 quiz'
#  '15 times "ted lasso" explored reality mental health'
#  '26 inconsiderate people made home public'
#  "31 food photos horrific, they'll hurt eyes even they'd destroy stomach"
#  'pete davidson admitted he\'s sure "how" boil water know think'
#  'best deals target right' '36 products make household run seamlessly'
#  'tell us time put medical care cost'
#  'billionaires rarely pay taxes — — 18 facts get angry'
#  'halle berry approved saweetie\'s "catwoman" halloween costume see'
#  '27 stylish home decor things amazon canada aren’t throw pillows candles'
#  'jason sudeikis looked back day allowed olivia wilde ellen degeneres cut hair tv'
#  'millennials able tick everything neopets quiz'
#  'miranda cosgrove revealed hole leg 2011 bus crash doctors explain'
#  "30 things '90s kids time makes zero sense today"
#  '35 affordable things make feel oh-so-fancy'
#  "here's tracee ellis ross 17 celebrities shared week #tbt"
#  'bet can\'t recognise even 10 minor characters "brooklyn nine-nine"'
#  'dwayne "the rock" johnson wants daniel craig\'s james bond successor, hope producers seeing right'
#  'kirsten dunst revealed reason jesse plemons decided second child'
#  '13 celebrities made big bought parents brand-new house'
#  '32 products fitness-related aches pains'
#  '25 stylish yet affordable things boohoo you’ll probably want wear time'
#  'alicia silverstone says got banned dating app twice thought profile fake'
#  '20 common business practices quite unethical, used often'
#  '18 outfits chandler, joey, ross wore "friends" human wear'
#  'lady gaga fans defending accent "house gucci" film’s dialect coach criticized'
#  'kate beckinsale revealed go hospital hurting putting leggings'
#  'wake "the great resignation", aussies sharing reasons they\'ve left jobs'
#  "go luxury shoe shopping spree, we'll reveal celebrity style soulmate"
#  'tell us popular movie costars date real life, 100%'
#  '33 subtly sexist things women deal often go unnoticed'
#  'netflix announced they\'ve cast uncle iroh firelord ozai "avatar: last airbender" can\'t stop screaming excitement'
#  'here\'s cast "dune" characters playing'
#  'florence pugh explained us dressing "black widow" character halloween, argument checks'
#  'steve "blue\'s clues" joined tiktok, hilariously, first video millennial'
#  't.j. osborne celebrated win cmas kissing boyfriend, first time same-sex kiss ever broadcasted awards'
#  "i'm applauding 18 famous women called hollywood way depicts women screen"
#  'olivia jade says lives fear "canceled again" following college admissions scandal'
#  'non-americans sharing american things wish common live'
#  '26 genuinely iconic teen movie outfits, ranked cuteness'
#  '"rich friend" grew 16/36 things house'
#  'feel superior single-use plastic friends 36 reusable products'
#  '"the mentalist" actor simon baker reportedly broken designer laura may gibbs attended anti-vax rally'
#  "27 stories people discovered mom dad's infidelity left speechless"
#  "trendiest foods past year i'm curious even tried bite"
#  'jason sudeikis perfect reason go birth name daniel'
#  "i'm begging freak guess generation based carb preferences"
#  '21 pregnant women whose halloween costumes made go, "damn, that"'
#  '15 abortion stories actual women prove safe easy access everything'
#  '22 things non-aussies hate australian lifestyle'
#  'food customs purely australian rest world too?'
#  '24 disney movies messed enough small ways ruin'
#  'spiritual abuse survivors sharing stories, heartbreaking reality talked enough'
#  'love "ratatouille," seeing 17 disney world details delight'
#  'here\'s cast "dune" side side original 1984 cast'
#  "24 celeb siblings can't even think one without mentioning other, looked like growing"
#  'seen 18/34 episodes, obsessed television halloween'
#  '25 times harry styles went way make fans hella happy concerts 2021'
#  "kourtney kardashian travis barker revealed they're engaged shared pictures proposal"
#  '15 celebrities use stage names, like 30% people know real names'
#  'megan fox full-on straddled machine gun kelly la concert, thereby turning pda 11'
#  "25 subtle traits rich australian families growing '00s"
#  '19 fun facts help get know "euphoria" actor sydney sweeney'
#  'could make across survive glass bridge "squid game?"'
#  "40 beauty products readers can't get enough"
#  'billie lourd got super honest generational trauma growing mom carrie fisher taught "what do" parent'
#  '25 "facts" everyone agrees true are...wait minute...completely false'
#  'timothée chalamet used youtube channel showed xbox 360 controllers'
#  'mindy kaling dressed issa rae, elle woods, ali wong female comedy icons halloween'
#  '"reba" first aired 20 years ago, here\'s cast looks like'
#  "people saying changing voicemail could save life lost — they're wrong here's instead"
#  'penn badgley weighed wild finale "you" season 3, could store character'
#  '18 hilarious "brooklyn nine-nine" cold opens fill void show left behind'
#  'aussies sharing common stereotypes foreigners actually believe australia'
#  'here’s taylor swift fans made john mayer’s name trending “all well” short film premiered'
#  'answers determine "halloween kills" character'
#  'andrew lloyd webber registered dog emotional support animal watching "cats" movie'
#  '24 jobs people claim total asshole would'
#  "chances are, birth control comes long list side effects — let's see many experienced"
#  'here\'s 12 "insecure" cast members looked like first episode compared'
#  'taylor swift revealed new music video "i bet think me" directed blake lively'
#  "here's anya taylor-joy jell-o wrestling tigger onesie emmy awards"
#  'sounds like idris elba would gladly play james bond role offered him, happened yet'
#  '34 cleaning products get job done first damn time'
#  'kristen stewart said wearing replica princess diana\'s wedding dress felt like "spooky day"'
#  '40 beauty products cheap people high standards'
#  "can't pass australian l-plates driving test, surrender licence asap"
#  "teachers revealing worst things students' parents ever said them, i'm deeply disturbed"
#  'tom holland shared another tribute zendaya instagram, made history cfda fashion awards'
#  'alan cumming says suicidal right landed role "goldeneye"'
#  '19 songs would tiktok famous released today'
#  'people tried 7/26 sweet, impress me, tried least 14/26'
#  'former "nice guys" shared made change ways, need men date women read asap'
#  'anyone 28 relate hilariously depressing tiktok "torn" natalie imbruglia'
#  "19 nostalgic things people miss '90s"
#  'people used wealthy anymore sharing things learned poor, happens often think'
#  '15 people tried change partners, case needed reminder toxic mindset'
#  "i'm sorry, literally 40 things growing up, congratulations! officially old"
#  '14 horrible bosses probably faked way top'
#  '34 beauty products anyone whose routine 10 minutes less'
#  'dakota johnson asked allegations surrounding previous male co-stars: armie hammer, shia labeouf, johnny depp'
#  'ferrell says turned $29 million "elf" sequel'
#  "susan sarandon opened final conversation david bowie can't remember"
#  'woodworkers get credit deserve, 25 photos prove'
#  'courteney cox neve campbell talked reprising roles new "scream" movie, i\'m clutching phone anticipation'
#  '44 problem-solving products that’ll make jump joy well work'
#  'get 10/14 lyric quiz adele’s "easy me," probably need hug'
#  '36 quick problem-solving products people simply time deal']

# %%
clean_title_vals = title_df['clean_title'].values

title_wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      stopwords=stop_words,
                      min_font_size=8).generate(str(clean_title_vals))

plt.figure(figsize=(10, 8))
plt.imshow(title_wordcloud)
plt.title("Title WordCloud", size=20, fontweight='bold')
plt.axis('off')
plt.tight_layout()
plt.show();

# %% [markdown]
# Basically the 3 most popular words that BuzzFeed uses in their headlines are "thing", "people", and "make". We don't need to know the context in which they use them just yet, but let's see if these 3 popular words translate into what their top n-gram combinations are...

# %%
# n-gram visualizations

def get_ngrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(n, n), stop_words='english').fit(corpus)
    bow = vec.transform(corpus)
    sum_words = bow.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:15]

top_n_unigrams = get_ngrams(title_df['clean_title'], 1)
x, y = map(list, zip(*top_n_unigrams))
plt.figure(figsize=(10, 8))
sns.barplot(x=y, y=x)
plt.title("What are BuzzFeed's favourite words to use in its titles?", size=18, fontweight='bold')
plt.show();

# %%
top_n_bigrams = get_ngrams(title_df['clean_title'], 2)
x, y = map(list, zip(*top_n_bigrams))
plt.figure(figsize=(10, 8))
sns.barplot(x=y, y=x)
plt.title("Which pairs of words are most popular?", size=20, fontweight='bold')
plt.show();

# %% [markdown]
# These pairings of words are a bit funny based off the time that they were collected in. We can obviously pick out which sort of topics BuzzFeed was covering at the time of scraping: Taylor Swift was re-releasing another album, there was obviously some sort of Kardashian drama going on, and it was around October that I collected the headlines.

# %% [markdown]
# We'll move on and start to do a bit of topic modeling with a cool library called `pyLDAvis`. First we'll process the text data a little bit more so the new topic modeling library can handle what we throw at it. We'll create a new function that will wrap all of our cleaning techniques into one:

# %%
def preprocess(df):
    corpus = []
    stem = PorterStemmer()
    lem = WordNetLemmatizer()
    for headline in title_df['clean_title']:
        words = [w for w in word_tokenize(headline) if (w not in stop_words)]
        words = [lem.lemmatize(w) for w in words if len(w)>2]
        
        corpus.append(words)
    return corpus

corpus = preprocess(title_df)

# %%
# create a Bag-of-Words model using gensim
dic = gensim.corpora.Dictionary(corpus)
bow_corpus = [dic.doc2bow(doc) for doc in corpus]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus,
                                       num_topics=3,
                                       id2word=dic,
                                       passes=10,
                                       workers=2,
                                       random_state=2021)
lda_model.show_topics()
# Out:
# [(0,
#   '0.012*"thing" + 0.011*"product" + 0.008*"people" + 0.008*"make" + 0.007*"sharing" + 0.007*"say" + 0.006*"time" + 0.005*"moment" + 0.005*"life" + 0.005*"movie"'),
#  (1,
#   '0.010*"people" + 0.008*"halloween" + 0.005*"celebrity" + 0.005*"know" + 0.005*"show" + 0.004*"say" + 0.004*"thing" + 0.004*"character" + 0.004*"tried" + 0.004*"name"'),
#  (2,
#   '0.008*"like" + 0.007*"people" + 0.006*"thing" + 0.005*"story" + 0.005*"woman" + 0.005*"get" + 0.004*"even" + 0.004*"house" + 0.004*"said" + 0.004*"enough"')]

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
vis = gensimvis.prepare(lda_model, bow_corpus, dic)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el56331405185287234089212601534"></div>
# <script type="text/javascript">
#
# var ldavis_el56331405185287234089212601534_data = {"mdsDat": {"x": [0.0658373484831956, -0.09310170057871628, 0.02726435209552068], "y": [0.06818480459842917, 0.021850780706314767, -0.09003558530474397], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [37.76136380114913, 33.214979214800806, 29.02365698405007]}, "tinfo": {"Term": ["product", "halloween", "moment", "even", "know", "enough", "woman", "house", "say", "name", "game", "kourtney", "right", "life", "friend", "like", "feel", "character", "actor", "season", "costume", "dress", "absolutely", "sharing", "side", "question", "show", "made", "true", "'re", "moment", "season", "scene", "tom", "product", "done", "believe", "breastfeeding", "zero", "covid-19", "routine", "simply", "award", "celebs", "boyfriend", "guy", "nice", "total", "problem-solving", "hot", "big", "two", "cleaning", "guess", "hank", "bieber", "fry", "journey", "emmy", "try", "life", "sharing", "best", "real", "home", "thing", "make", "say", "time", "tell", "movie", "ever", "people", "kid", "parent", "'ve", "made", "shared", "tweet", "job", "woman", "first", "prove", "australian", "'ll", "character", "fan", "said", "enough", "even", "game", "side", "question", "completely", "disability", "hear", "female", "easy", "chance", "simon", "feeling", "recalled", "worst", "dog", "squid", "house", "bond", "hadid", "james", "zayn", "baker", "led", "doctor", "cardi", "seeing", "actual", "celeb", "co-star", "dress", "absolutely", "true", "like", "story", "photo", "would", "woman", "thought", "get", "adele", "n't", "said", "way", "people", "want", "american", "wedding", "thing", "revealed", "food", "cast", "fact", "day", "make", "movie", "kourtney", "baby", "barker", "travis", "pregnant", "emily", "wore", "getting", "recognize", "city", "front", "stylish", "important", "wear", "usa", "millennials", "medium", "social", "told", "resident", "personality", "jolie", "angelina", "twin", "already", "passing", "really", "amazon", "canada", "scott", "name", "halloween", "costume", "know", "'re", "right", "actor", "tried", "show", "friend", "feel", "celebrity", "kardashian", "engagement", "hilarious", "affordable", "used", "people", "famous", "character", "well", "year", "film", "say", "could", "'ll", "like", "thing", "taylor", "swift", "fan", "cast", "first", "new", "make", "made"], "Freq": [15.0, 9.0, 6.0, 5.0, 7.0, 4.0, 10.0, 5.0, 12.0, 4.0, 3.0, 3.0, 5.0, 7.0, 5.0, 14.0, 5.0, 7.0, 5.0, 4.0, 4.0, 4.0, 4.0, 11.0, 3.0, 3.0, 7.0, 6.0, 4.0, 3.0, 5.53778736596491, 3.5783163189229645, 2.913728788592819, 2.9034799591911526, 13.543779452287486, 2.242498065019566, 2.2422955336773773, 2.2422250401034813, 2.2420529366515876, 2.241862521392412, 2.2418388399574316, 2.241738193858764, 2.2416321781323973, 2.2415713223518074, 2.2415662280896314, 2.2414454803077826, 2.2411413390875956, 2.2408709301439798, 2.239526733343307, 2.2388507109842677, 2.2332163193347823, 2.2272258800640183, 2.2244039341840036, 2.722720667446249, 1.5697670123940823, 1.5696564531365857, 1.5695881624868742, 1.5695483721687964, 1.5695384590099672, 1.569541074982436, 5.536249174153262, 8.415085571226337, 2.9616966366081363, 2.9291321852200904, 2.927687893051796, 14.675649608386072, 9.129972469455298, 7.729859945676112, 7.4009501474235595, 4.112034732239799, 5.390584667587531, 3.8987963524189895, 9.769684579896975, 4.303792673705581, 3.2225941796929467, 3.2179347196777504, 3.9561701359699777, 4.190027610789777, 3.0846834155247036, 3.5538261354012146, 4.904728086559647, 4.285310415165307, 3.588892007200468, 3.668620790007629, 3.5843325048701318, 3.42001886825717, 3.458538649811793, 2.9761715006917497, 4.102217399555637, 4.650829797663526, 3.4648906934992643, 2.829860400588655, 2.811422244876373, 2.1767349243330667, 2.1764970720274937, 2.176405031420449, 2.1760683565683645, 2.1758404349598672, 2.1747906876153107, 2.1740335325163063, 2.173771216786229, 2.173762497149772, 2.1736755429973273, 2.153082668231705, 2.144087394377957, 4.24419342689175, 1.5237599829124215, 1.52375840 ...

# %%
def show_wordcloud(data):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stop_words,
        max_words=100,
        max_font_size=30,
        scale=3,
        random_state=42
    )
    wordcloud = wordcloud.generate(str(data))
    
    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    plt.imshow(wordcloud)
    plt.title("WordCloud based off LDA", size=28, fontweight='bold')
    plt.show();
    
show_wordcloud(corpus)

# %% [markdown]
# Moving on to use the TextBlob library to calculate the polarity and sentiment of the headlines.

# %%
from textblob import TextBlob

# %%
def polarity(text):
    # calculating polarity scores of our headlines
    # will give a score between -1.0 and 1.0
    return TextBlob(text).sentiment.polarity

title_df['polarity_score'] = title_df['title'].apply(lambda x: polarity(x))

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.histplot(title_df.polarity_score, kde=True, color=colors[2])
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
ax.set_title("Polarity Score of Titles", size=20, fontweight='bold')
ax.set_xlabel("Polarity Score")
plt.show();

# %%
title_df['polarity_score'].describe()
# Out:
# count    375.000000
# mean       0.081467
# std        0.293888
# min       -0.900000
# 25%        0.000000
# 50%        0.000000
# 75%        0.246429
# max        1.000000
# Name: polarity_score, dtype: float64

# %% [markdown]
# We can see that our mean polarity score is around 0.08 which is a very low score, meaning that our headlines, on average, are quite neutral and maybe even slightly more positive in their sentiment. BuzzFeed isn't generally a news outlet that gets too political, but we can also note that my period of collection of the headlines wasn't any significant point in time so there shouldn't be many polarizing topics unless BuzzFeed editors are feeling frisky. We'll have a better conclusion once we calculate the sentiments and visualize them.

# %% [markdown]
# So we've got polarity scores to quantitatively show what our headlines are like, but let's classify those scores as either positive, negative or neutral sentiment. We'll do this by creating a function that specifies a threshold, and if the scores are above, below, or equal to the threshold then we bin them into their corresponding category.

# %%
def sentiment(x):
    if x < 0:
        return 'negative'
    elif x == 0:
        return 'neutral'
    else:
        return 'positive'
    
title_df['sentiment'] = title_df['polarity_score'].apply(lambda x: sentiment(x))

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(title_df.sentiment.value_counts().index,
            title_df.sentiment.value_counts(), edgecolor='black')
ax.set_title("Title Sentiment Label Count based on Polarity Score", size=20, fontweight='bold')
ax.set_xlabel("Sentiment Label")
ax.set_ylabel("Count")
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
plt.tight_layout()
plt.show();

# %%
pct_sent = round((title_df.sentiment.value_counts() / (len(title_df)))*100, 2)
print(pct_sent)
# Out:
# positive    42.13
# neutral     36.00
# negative    21.87
# Name: sentiment, dtype: float64

# %% [markdown]
# Let's take a look at a few headlines from each sentiment category...

# %%
pos_headlines = title_df[title_df['sentiment'] == 'positive']['title']
print(pos_headlines.sample(3).tolist())
# Out:
# ["here are 17 historical events most people weren't taught in school, but should definitely know about", 'taylor swift revealed that her new music video for "i bet you think about me" was directed by blake lively', 'she became the first latinx woman with a disability to mt. kilimanjaro, proving "there is nothing a disabled person can\'t do"']

# %%
neu_headlines = title_df[title_df['sentiment'] == 'neutral']['title']
print(neu_headlines.sample(3).tolist())
# Out:
# ['how well do you remember the opening monologue from "the lord of the rings: the fellowship of the ring"?', 'australians are explaining what a "bogan" is to the rest of the world and i\'m cackling', 'a$ap rocky stopped his show and demanded fallen fans be picked up in a resurfaced video']

# %%
neg_headlines = title_df[title_df['sentiment'] == 'negative']['title']
print(neg_headlines.sample(3).tolist())
# Out:
# ["these are the trendiest foods from the past year and i'm just curious if you've even tried a bite", '16 husbands whose hysterical fails left them very, very embarrassed', 'unequal pay, unfulfillment, and 17 other reasons these women are leaving their jobs in tech']

# %% [markdown]
# We see some interesting headlines when we print out the results. Some even don't make sense being in the category that they're in. This could be due to the fact that some sentiment analysis techniques/libraries aren't great at detecting negative sentiments. One library that works pretty well at detecting negative sentiments is the VADER library. We can import it via `nltk` and work from there.

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

def vader_score(sent):
    ss = sia.polarity_scores(sent)
    
    return np.argmax(list(ss.values())[::-1])

title_df['polarity'] = title_df['title'].apply(lambda x: vader_score(x))
polarity = title_df['polarity'].replace({0:'neg', 2:'neu', 3:'pos'})
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jordansamek/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(polarity.value_counts().index,
            polarity.value_counts())
ax.set_title("Sentiment Label (VADER calculation)", size=20, fontweight='bold')
ax.set_xlabel("VADER Sentiment Label")
ax.set_ylabel("Sentiment Count")
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
plt.tight_layout()
plt.show();

# %%
title_df['polarity'].value_counts()
# Out:
# 2    343
# 0     28
# 3      4
# Name: polarity, dtype: int64

# %%
title_df['polarity'].describe()
# Out:
# count    375.000000
# mean       1.861333
# std        0.539333
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        3.000000
# Name: polarity, dtype: float64

# %%
def vader_sentiment(score):
    emotion = ""
    if score == 3.0:
        emotion = "positive"
    elif score == 2.0:
        emotion = "neutral"
    else:
        emotion = "negative"
    return emotion

# %%
title_df['vader_sentiment'] = title_df['polarity'].apply(lambda x: vader_sentiment(x))
title_df['vader_sentiment'].value_counts()
# Out:
# neutral     343
# negative     28
# positive      4
# Name: vader_sentiment, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(title_df['vader_sentiment'].value_counts().index,
            title_df['vader_sentiment'].value_counts(), edgecolor='black')
ax.set_title("Sentiment Label (VADER calculation)", size=20, fontweight='bold')
ax.set_xlabel("VADER Sentiment Label")
ax.set_ylabel("Sentiment Count")
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
plt.show();

# %% [markdown]
# Visualize NER with SpaCy

# %%
# hide
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 3.9 MB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.10.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: jinja2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: setuptools in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (59.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.21.4)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.61.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.26.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: zipp>=0.5 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.8)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
# from IPython.core.display import display, HTML

rand_title = np.random.randint(0, 381)
text = title_df['title'][rand_title]
# print(text)

nlp = spacy.load('en_core_web_sm')
doc = nlp(text)

# html = displacy.render(doc, style='ent', jupyter=True)
# display(HTML(html))

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">she became the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  latinx woman with a disability to mt. kilimanjaro, proving &quot;there is nothing a disabled person can't do&quot;</div></span>

# %% [markdown]
# I've run the above code multiple times and it seems like the visualizer doesn't pick up on some basic names. For now we'll move along. What we can do that might be useful is to apply NER on our headlines and then store the entity types.

# %%
from collections import Counter

def ner_types(text):
    doc = nlp(text)
    return [X.label_ for X in doc.ents]

ent = title_df['title'].apply(lambda x: ner_types(x))
ent = [x for sub in ent for x in sub]

counter = Counter(ent)
count = counter.most_common()

fig, ax = plt.subplots(figsize=(10, 8))
x, y = map(list, zip(*count))
sns.barplot(x=y, y=x, edgecolor='black')
ax.set_title("Count of NER Labels", size=20, fontweight='bold')
ax.set_xlabel("Label Count")
ax.set_ylabel("NER Label Type")
plt.tight_layout()
plt.show();

# %%
title_df.head()
# Out:
#                                                title  title_len  \
# 0  71 brilliant details from "community" that sho...        114
# 1  kelsea ballerini shared her struggle with buli...         63
# 2  people who practice polyamory — do you have ru...         88
# 3  21 celebrities who appeared in their significa...         76
# 4  mindy kaling wants her kids' "consent" before ...         82
#
#                                          clean_title  polarity_score  \
# 0  71 brilliant details "community" emmy "best at...        0.950000
# 1  kelsea ballerini shared struggle bulimia teenager        0.000000
# 2  people practice polyamory — rules put place re...        0.000000
# 3  21 celebrities appeared significant other's mo...        0.125000
# 4  mindy kaling wants kids' "consent" sharing pic...        0.116667
#
#   sentiment  polarity vader_sentiment
# 0  positive         0        negative
# 1   neutral         2         neutral
# 2   neutral         2         neutral
# 3  positive         2         neutral
# 4  positive         2         neutral

# %% [markdown]
# Let's create a stripped down dataset for our deep learning models to come...

# %%
model_df = title_df[['clean_title']]
model_df.to_csv('../data/clean_titles.csv', index=False)
