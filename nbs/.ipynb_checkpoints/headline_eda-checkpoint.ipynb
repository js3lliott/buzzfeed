# %% [markdown]
# # BuzzFeed Headline Exploratory Data Analysis
#
# In this notebook we're going to explore what exactly makes a BuzzFeed headline and the tricks they use to grab your attention.

# %%
import pandas as pd
import numpy as np
import matplotlib
import re
import string
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# matplotlib.style.use('fivethirtyeight')
sns.set_style('ticks')
plt.rcParams['font.family'] = 'monospace'
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

colors = ['#006ba6', '#0496ff', '#ffbc42', '#d81159', '#8f2d56', '#41ead4', '#ff206e']
sns.color_palette(colors)
sns.set_palette(colors)

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from langdetect import detect
from wordcloud import WordCloud
import gensim
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

stop_words = stopwords.words('english')

# %config InlineBackend.figure_format = 'retina'
pd.set_option("display.max_rows", None)


print('Setup Complete.')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jordansamek/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jordansamek/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Setup Complete.
# /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages/sklearn/decomposition/_lda.py:28: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps
# /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages/matplotlib_inline/config.py:75: DeprecationWarning: InlineBackend._figure_format_changed is deprecated in traitlets 4.1: use @observe and @unobserve instead.
#   def _figure_format_changed(self, name, old, new):

# %%
data = pd.read_csv('../data/buzzfeed_headlines.csv')
print(data.shape)

# let's shuffle the dataset so everything is mixed together appropriately

data = data.sample(frac=1).reset_index().drop('index', axis=1)
data.head()
# Out:
# (960, 3)
#                                              content  \
# 0  Keep up with the latest daily buzz with the Bu...
# 1  Vox / Via youtube.comSome examples are the sen...
# 2  Nintendo\r\nSorry, I mean having a super relax...
# 3  ABC Studios\r\nDuring season 4 of HTGAWM, Viol...
# 4  "...Now that they're older, it's getting harde...
#
#                                          description  \
# 0                      "Mi musa 💘"View Entire Post ›
# 1  Start practicing your "Um, actually..."View En...
# 2  There's 0% chance Animal Crossing won't be som...
# 3  How to get away with not knowing these facts.V...
# 4  "My current husband has no idea I've already b...
#
#                                                title
# 0  Rauw Alejandro Celebrated Valentine's Day With...
# 1      36 Pieces Of Trivia I Didn't Believe At First
# 2  Calling All Video Game Lovers, Tell Us Your Fa...
# 3  14 Facts That Went Over Your Head In "How To G...
# 4  36 Wild Secrets People Are Keeping From Their ...

# %% [markdown]
# ## Exploring our Text Analytics
#
# Diving into the bits'n'pieces of the format the headlines are in and what they're comprised of.

# %% [markdown]
# For simpler pre-processing, we'll convert the `title` column text into lowercase first.

# %%
def lower_title(text):
    text = str(text).lower()
    return text

data['title'] = data['title'].apply(lower_title)

data.head()
# Out:
#                                              content  \
# 0  Keep up with the latest daily buzz with the Bu...
# 1  Vox / Via youtube.comSome examples are the sen...
# 2  Nintendo\r\nSorry, I mean having a super relax...
# 3  ABC Studios\r\nDuring season 4 of HTGAWM, Viol...
# 4  "...Now that they're older, it's getting harde...
#
#                                          description  \
# 0                      "Mi musa 💘"View Entire Post ›
# 1  Start practicing your "Um, actually..."View En...
# 2  There's 0% chance Animal Crossing won't be som...
# 3  How to get away with not knowing these facts.V...
# 4  "My current husband has no idea I've already b...
#
#                                                title
# 0  rauw alejandro celebrated valentine's day with...
# 1      36 pieces of trivia i didn't believe at first
# 2  calling all video game lovers, tell us your fa...
# 3  14 facts that went over your head in "how to g...
# 4  36 wild secrets people are keeping from their ...

# %% [markdown]
# Let's see how long each title is, on a character-based level, and maybe what the average title length is:

# %%
data['title_len'] = data['title'].apply(len)
data.sample(4)
# Out:
#                                                content  \
# 173  New Line Cinema\r\n*For the purposes of this p...
# 659  If you've been the target of revenge porn, the...
# 353  "I got locked down in Melbourne with one of my...
# 371  Taylor Hill / FilmMagic via Getty Images\r\nTh...
#
#                                            description  \
# 173  "Oh...oh no." — All of us watching these coupl...
# 659  "It wasn’t some random strangers seeing these ...
# 353  "I got locked down in Melbourne with one of my...
# 371  It seems like the fourth month really makes or...
#
#                                                  title  title_len
# 173  we want to know which movie couples you think ...         90
# 659  people who've had their nudes leaked are shari...         88
# 353  "succession" star sarah snook secretly got mar...        123
# 371  21 celebrity couples that have made their marr...        126

# %% [markdown]
# What do our simple stats for title length look like?

# %%
data['title_len'].describe()
# Out:
# count    960.000000
# mean      87.317708
# std       24.947831
# min       31.000000
# 25%       68.000000
# 50%       86.000000
# 75%      104.000000
# max      192.000000
# Name: title_len, dtype: float64

# %% [markdown]
# Taking a look at what each title's length looks like, starting from the minimum length to the max.

# %%
data.groupby(['title_len'], as_index=False)['title'].max()
# Out:
#      title_len                                              title
# 0           31                    【速報】hpvワクチン、積極的勧奨の再開を了承　厚労省の審議会
# 1           35                what's your nightmare period story?
# 2           37              デンマークでコロナの規制を全て撤廃　それでも国民の表情が落ち着いているわけ
# 3           38             トランスジェンダーは婦人科を受診しちゃいけないの？　当事者や医師に聞いてみた
# 4           39            how would you die on "game of thrones?"
# 5           40           here's how eric nam would rank his songs
# 6           41          27 weird '90s cult movies worth your time
# 7           42         these random questions reveal if you floss
# 8           43        自民党「影の幹事長」がdappiへの関与を否定。群馬の村で見えた“親族のつながり“とは
# 9           44       every kill in the "scream" franchise, ranked
# 10          45      36 pieces of trivia i didn't believe at first
# 11          46     25 must-watch performances found in bad movies
# 12          47    新型コロナ感染者数「近くピークになりそう」 西浦博さんが今伝えたい、良いニュースと悪いニュース
# 13          48   ピークアウトは早く、流行規模も小さい？　当初の想定と違ったオミクロン流行とどう向き合えば良いのか
# 14          49  40 things you deserve to own if you don’t already
# 15          50  these 90s rom-coms will 100% make your life be...
# 16          51  you can only save one: ultimate aussie food ed...
# 17          52  what’s it like to have never been in a relatio...
# 18          53  「オミクロン株は制御不能ではない」　8割おじさんが「鍵を握る」と話すクラスターが起きやすい場...
# 19          54  伊藤詩織さん、控訴審の東京高裁でも勝訴　山口敬之さんに引き続き損害賠償命じる判決　山口さんの...
# 20          55  which of these classic aussie pub foods would ...
# 21          56  原爆をテーマにした米国のビールに批判。名前は「黒い雨」に「必要悪」。広島・長崎に投下の原爆の...
# 22          57  these 18 posts are straight out of an alternat...
# 23          58  コロナで休園、保護者が有給求めたら「クビにする」「不公平」… 小学校休業等対応助成金、企業の...
# 24          59  your answers will predict which horror icon wi...
# 25          60  the ultimate bts song quiz: see how you rank i...
# 26          61  there's a "twin peaks" resident in us all, whi...
# 27          62  tell us the most unprofessional way/reason you...
# 28          63  these 17 snacks are some of the best trader jo...
# 29          64  what the "encanto" cast was like in their firs...
# 30          65  the data is out — this is what parents named t...
# 31          66  will ferrell says he turned down $29 million t...
# 32          67  the movie songs you know and don't are a total...
# 33          68  only people who can see blue perfectly well ca...
# 34          69  your answers will determine which "halloween k...
# 35          70  would you ever wear any of these 20 raven baxt...
# 36          71  want to help out with a tasty research study? ...
# 37          72  what money advice have you gotten from boomers...
# 38          73  these 20 common business practices are quite u...
# 39          74  women are sharing their most used life hacks, ...
# 40          75  your guide to the social media profiles of the...
# 41          76  think you can decipher these countries by desc...
# 42          77  we want to hear the most impossible coincidenc...
# 43          78  true crime: everything you need to know about ...
# 44          79  wanna know your dominant personality trait? ju...
# 45          80  mariano's walk in "encanto" is now a tiktok tr...
# 46          81  these 21 tweets about wordle are honestly just...
# 47          82  we'll tell you your soulmate's initial based o...
# 48          83  those "evil be like memes" are taking over twi...
# 49          84  kristen bell revealed that her and dax shepard...
# 50          85  werewolves hostages in an abandoned bank vault...
# 51          86  we asked british people to guess the meaning o...
# 52          87  we know exaaaaactly how old you are based on h...
# 53          88  rihanna perfectly replicated an instagram post...
# 54          89  timothée chalamet used to have a youtube chann...
# 55          90  zendaya defended "euphoria" after an anti-drug...
# 56          91  zendaya wore a bold gold breastplate on the re...
# 57          92  wonho read the internet's thirstiest tweets ab...
# 58          93  whoopi goldberg has been suspended from "the v...
# 59          94  true crime: everything you need to know about ...
# 60          95  tell us your witch opinions and we'll reveal w...
# 61          96  women are sharing how young they were when the...
# 62          97  these are the trendiest foods from the past ye...
# 63          98  two months ago, i switched one thing in my ski...
# 64          99  the "and just like that" finale (kind of) feat...
# 65         100  women are pointing out female issues that don'...
# 66         101  sarah jessica parker finally said something ab...
# 67         102  sure, you've probably tried 13/40 of these cho...
# 68         103  women are sharing their creepiest "nice guy" s...
# 69         104  the good, the bad, and the ugly celebrity hall...
# 70         105  queen latifah spoke out about chris noth's sex...
# 71         106  three cheers for libraries like this one, whic...
# 72         107  these 16 iconic characters wouldn't be the sam...
# 73         108  nicole kidman is unveiled as lucille ball in t...
# 74         109  women are sharing why they regret giving birth...
# 75         110  the fbi vs. dr. martin luther king jr.: the li...
# 76         111  “the size of your body is the least interestin...
# 77         112  salma hayek and lauren ridloff say that marvel...
# 78         113  robert pattinson explaining why he pretended n...
# 79         114  these 35 bad parents have zero excuses for the...
# 80         115  watch seth rogen and paul rudd take increasing...
# 81         116  spiritual abuse survivors are sharing their st...
# 82         117  nick cannon says he's always been insecure abo...
# 83         118  this might be our last olympics with leslie jo...
# 84         119  ummm, this is hard, but choose one chocolate d...
# 85         120  people are sharing exactly how they caught the...
# 86         121  machine gun kelly said he filmed his engagemen...
# 87         122  what they didn't teach you in school: the assa...
# 88         123  women are sharing the most embarrassing thing ...
# 89         124  what they never taught you in school: the murd...
# 90         125  women on tiktok are thanking this mom for educ...
# 91         126  kanye west sent kim kardashian a truck of rose...
# 92         127  julia fox says she's not dating kanye west for...
# 93         128  princess mako of japan gave up her royal title...
# 94         129  surgeons, librarians, and people of all indust...
# 95         130  dakota johnson was asked about the allegations...
# 96         131  people are saying changing your voicemail coul...
# 97         133  this australian tiktoker documented what ameri...
# 98         135  laura coates reflected on being snubbed by "je...
# 99         136  dakota johnson revealed that, on the set of “t...
# 100        137  this uncle proved you can tackle conversations...
# 101        138  model linda evangelista got real about the rar...
# 102        139  the new kanye west documentary reportedly delv...
# 103        140  more details are coming out about the british ...
# 104        142  matthew mcconaughey clarified his stance on va...
# 105        143  this person is going viral for roasting people...
# 106        144  travis barker's son posted this tiktok from hi...
# 107        145  netflix have announced who they've cast for un...
# 108        146  twitter is currently predicting scott disick's...
# 109        149  dakota johnson reflected on how "fifty shades ...
# 110        150  scott disick had lunch with kris jenner while ...
# 111        151  t.j. osborne celebrated his win at the cmas by...
# 112        152  as a "got" fan, i was not well when i realized...
# 113        157  these 13 rules are considered part of the unsp...
# 114        159  nicola coughlan got candid about being overwhe...
# 115        160  zendaya and tom holland's adorable instagram i...
# 116        163  in a series of instagram posts shared sunday m...
# 117        174  here's why kristen bell hated filming this "th...
# 118        192  melanie lynskey shared that it was "really imp...

# %% [markdown]
# We should probably remove the 3 titles that aren't English, just for the sake of consistency of our values that we'll eventually be processing and putting into our ML model. We'll make use of the handy library `langdetect` to easily detect and extract which headlines aren't in English.

# %%
def detect_lang(txt):
    try:
        return detect(txt)
    except:
        return np.nan
    
data['language'] = data.title.apply(detect_lang)

# %%
data = data[data.language == "en"]
data.groupby(['title_len'], as_index=False)['title'].max()
# Out:
#      title_len                                              title
# 0           35                what's your nightmare period story?
# 1           38             just 34 very nice things for your home
# 2           39            how would you die on "game of thrones?"
# 3           40           here's how eric nam would rank his songs
# 4           41          27 weird '90s cult movies worth your time
# 5           42         these random questions reveal if you floss
# 6           43        20 forgotten movies from the disney catalog
# 7           44       every kill in the "scream" franchise, ranked
# 8           45      36 pieces of trivia i didn't believe at first
# 9           46     25 must-watch performances found in bad movies
# 10          47    how much money could you win in the "cash cab"?
# 11          48   your soup opinions will reveal your best quality
# 12          49  40 things you deserve to own if you don’t already
# 13          50  these 90s rom-coms will 100% make your life be...
# 14          51  you can only save one: ultimate aussie food ed...
# 15          52  what’s it like to have never been in a relatio...
# 16          53  the 50 best "parks and recreation" quotes of a...
# 17          54  what are some misconceptions about open relati...
# 18          55  which of these classic aussie pub foods would ...
# 19          56  top 5 digital marketing strategies that worked...
# 20          57  these 18 posts are straight out of an alternat...
# 21          58  your zodiac sign will reveal the next book you...
# 22          59  your answers will predict which horror icon wi...
# 23          60  the ultimate bts song quiz: see how you rank i...
# 24          61  there's a "twin peaks" resident in us all, whi...
# 25          62  tell us the most unprofessional way/reason you...
# 26          63  these 17 snacks are some of the best trader jo...
# 27          64  what the "encanto" cast was like in their firs...
# 28          65  the data is out — this is what parents named t...
# 29          66  will ferrell says he turned down $29 million t...
# 30          67  the movie songs you know and don't are a total...
# 31          68  only people who can see blue perfectly well ca...
# 32          69  your answers will determine which "halloween k...
# 33          70  would you ever wear any of these 20 raven baxt...
# 34          71  want to help out with a tasty research study? ...
# 35          72  what money advice have you gotten from boomers...
# 36          73  these 20 common business practices are quite u...
# 37          74  women are sharing their most used life hacks, ...
# 38          75  your guide to the social media profiles of the...
# 39          76  think you can decipher these countries by desc...
# 40          77  we want to hear the most impossible coincidenc...
# 41          78  true crime: everything you need to know about ...
# 42          79  wanna know your dominant personality trait? ju...
# 43          80  mariano's walk in "encanto" is now a tiktok tr...
# 44          81  these 21 tweets about wordle are honestly just...
# 45          82  we'll tell you your soulmate's initial based o...
# 46          83  those "evil be like memes" are taking over twi...
# 47          84  kristen bell revealed that her and dax shepard...
# 48          85  werewolves hostages in an abandoned bank vault...
# 49          86  we asked british people to guess the meaning o...
# 50          87  we know exaaaaactly how old you are based on h...
# 51          88  rihanna perfectly replicated an instagram post...
# 52          89  timothée chalamet used to have a youtube chann...
# 53          90  zendaya defended "euphoria" after an anti-drug...
# 54          91  zendaya wore a bold gold breastplate on the re...
# 55          92  wonho read the internet's thirstiest tweets ab...
# 56          93  whoopi goldberg has been suspended from "the v...
# 57          94  true crime: everything you need to know about ...
# 58          95  tell us your witch opinions and we'll reveal w...
# 59          96  women are sharing how young they were when the...
# 60          97  these are the trendiest foods from the past ye...
# 61          98  two months ago, i switched one thing in my ski...
# 62          99  the "and just like that" finale (kind of) feat...
# 63         100  women are pointing out female issues that don'...
# 64         101  sarah jessica parker finally said something ab...
# 65         102  sure, you've probably tried 13/40 of these cho...
# 66         103  women are sharing their creepiest "nice guy" s...
# 67         104  the good, the bad, and the ugly celebrity hall...
# 68         105  queen latifah spoke out about chris noth's sex...
# 69         106  three cheers for libraries like this one, whic...
# 70         107  these 16 iconic characters wouldn't be the sam...
# 71         108  nicole kidman is unveiled as lucille ball in t...
# 72         109  women are sharing why they regret giving birth...
# 73         110  the fbi vs. dr. martin luther king jr.: the li...
# 74         111  “the size of your body is the least interestin...
# 75         112  salma hayek and lauren ridloff say that marvel...
# 76         113  robert pattinson explaining why he pretended n...
# 77         114  these 35 bad parents have zero excuses for the...
# 78         115  watch seth rogen and paul rudd take increasing...
# 79         116  spiritual abuse survivors are sharing their st...
# 80         117  nick cannon says he's always been insecure abo...
# 81         118  this might be our last olympics with leslie jo...
# 82         119  ummm, this is hard, but choose one chocolate d...
# 83         120  people are sharing exactly how they caught the...
# 84         121  machine gun kelly said he filmed his engagemen...
# 85         122  what they didn't teach you in school: the assa...
# 86         123  women are sharing the most embarrassing thing ...
# 87         124  what they never taught you in school: the murd...
# 88         125  women on tiktok are thanking this mom for educ...
# 89         126  kanye west sent kim kardashian a truck of rose...
# 90         127  julia fox says she's not dating kanye west for...
# 91         128  princess mako of japan gave up her royal title...
# 92         129  surgeons, librarians, and people of all indust...
# 93         130  dakota johnson was asked about the allegations...
# 94         131  people are saying changing your voicemail coul...
# 95         133  this australian tiktoker documented what ameri...
# 96         135  laura coates reflected on being snubbed by "je...
# 97         136  dakota johnson revealed that, on the set of “t...
# 98         137  this uncle proved you can tackle conversations...
# 99         138  model linda evangelista got real about the rar...
# 100        139  the new kanye west documentary reportedly delv...
# 101        140  more details are coming out about the british ...
# 102        142  matthew mcconaughey clarified his stance on va...
# 103        143  this person is going viral for roasting people...
# 104        144  travis barker's son posted this tiktok from hi...
# 105        145  netflix have announced who they've cast for un...
# 106        146  twitter is currently predicting scott disick's...
# 107        149  dakota johnson reflected on how "fifty shades ...
# 108        150  scott disick had lunch with kris jenner while ...
# 109        151  t.j. osborne celebrated his win at the cmas by...
# 110        152  as a "got" fan, i was not well when i realized...
# 111        157  these 13 rules are considered part of the unsp...
# 112        159  nicola coughlan got candid about being overwhe...
# 113        160  zendaya and tom holland's adorable instagram i...
# 114        163  in a series of instagram posts shared sunday m...
# 115        174  here's why kristen bell hated filming this "th...
# 116        192  melanie lynskey shared that it was "really imp...

# %% [markdown]
# Dropping our `language` column since it's not needed anymore.

# %%
data = data.drop('language', axis=1)

# %%
data.head()
# Out:
#                                              content  \
# 0  Keep up with the latest daily buzz with the Bu...
# 1  Vox / Via youtube.comSome examples are the sen...
# 2  Nintendo\r\nSorry, I mean having a super relax...
# 3  ABC Studios\r\nDuring season 4 of HTGAWM, Viol...
# 4  "...Now that they're older, it's getting harde...
#
#                                          description  \
# 0                      "Mi musa 💘"View Entire Post ›
# 1  Start practicing your "Um, actually..."View En...
# 2  There's 0% chance Animal Crossing won't be som...
# 3  How to get away with not knowing these facts.V...
# 4  "My current husband has no idea I've already b...
#
#                                                title  title_len
# 0  rauw alejandro celebrated valentine's day with...        103
# 1      36 pieces of trivia i didn't believe at first         45
# 2  calling all video game lovers, tell us your fa...         73
# 3  14 facts that went over your head in "how to g...         66
# 4  36 wild secrets people are keeping from their ...         97

# %% [markdown]
# Before cleaning our `title` column to be put into an ML pipeline, let's just do some basic text analytics to get a sense of what each title consists of.

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 8))

plt.subplot(1, 2, 1)
sns.distplot(data['title_len']).set_title('Distribution of Title Lengths', fontsize=20, fontweight='bold')
plt.axvline(np.array(data['title_len'].mean()), ls='dashed')
plt.annotate(round(data['title_len'].mean(),2), xy=(90, 0.0165), xycoords='data', xytext=(110, 0.0164),
             arrowprops=dict(facecolor='blue', shrink=0.05))


title_word_len = data['title'].str.split().map(lambda x: len(x))
word_len_mean = round(title_word_len.mean(), 2)

plt.subplot(1, 2, 2)
sns.distplot(title_word_len).set_title('Distribution of Word Lengths', fontsize=20, fontweight='bold')
plt.axvline(word_len_mean, ls='dashed')
plt.annotate(word_len_mean, xy=(15.7, 0.095), xycoords='data', xytext=(20, 0.094),
             arrowprops=dict(facecolor='blue', shrink=0.05))
plt.xlabel("Number of words in title")

# ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
# ax.set_ylabel('')

plt.tight_layout()
plt.show();

# %%
min_title_words = data.title.str.split().map(lambda x: len(x)).min()
max_title_words = data.title.str.split().map(lambda x: len(x)).max()

print(f"The minimum amount of words in our titles is {min_title_words}")
print(f"The maxmimum amount of words in our titles is {max_title_words}")
# Out:
# The minimum amount of words in our titles is 5
# The maxmimum amount of words in our titles is 30

# %% [markdown]
# If anyone has ever seen any sort of clickbait headlines (which BuzzFeed apparently denies their headlines are clickbait), they've most likely noticed it probably has an odd number thrown in there like "27 Things You Shouldn't Do on a First Date!!" to grab your attention. This type of headline works in many different ways, but one major way is because we humans love lists, especially numbered lists. So let's check out how many headlines of BuzzFeed's contain numbers in them:

# %%
num_in_headline_count = 0
no_num_headline_count = 0
for line in data.title:
    if bool(re.search(r'\d+', line)) == True:
        num_in_headline_count += 1
    else:
        no_num_headline_count += 1

# %%
# Headlines with numbers - {num_in_headline_count}
# Headlines without numbers - {no_num_headline_count}
num_in_headline_count, no_num_headline_count
# Out:
# (456, 486)

# %%
headline_nums = {'num_in_headline_count': num_in_headline_count, 'no_num_headline_count': no_num_headline_count}
headline_numbers = pd.DataFrame(headline_nums, index=[0])

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(data=headline_numbers, ax=ax, alpha=0.8, zorder=2, palette=colors[-2:], edgecolor='black')
ax.set_title("# of Headlines with & without numbers in them", fontweight='bold', fontsize=20)
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
ax.set_xlabel("Numbers in Headlines", fontweight='bold', fontsize=15)
ax.set_ylabel("Count", fontweight='bold', fontsize=15)
plt.tight_layout()
plt.show();

# %% [markdown]
# My guess would have been that there were more headlines with numbers in them than without, but as we can see the headlines are relatively balanced when it comes to titles containing numbers. Even more surprisingly, headlines without numbers have the slight edge over headlines that include digits.

# %% [markdown]
# For simplicity sake, let's cut down our data so that it just includes our title text and our text length. We can come back later and do some analysis on the `content` and `description` features of our original dataset, but for now it will be easier to just work with our necessary features.

# %%
title_df = data[['title', 'title_len']]
title_df.sample(5)
# Out:
#                                                  title  title_len
# 94   36 nail products for anyone who’s sunk their c...         66
# 765  71 brilliant details from "community" that sho...        114
# 6     rate these creamy foods and we'll guess your age         48
# 99   people look down on these things because women...         88
# 947  15 types of dirty talk straight men said ruine...         66

# %% [markdown]
# Remove stopwords from the titles and then we'll make a quick wordcloud to visualize popular words before we fully clean the text for other NLP analysis.

# %%
title_df['clean_title'] = title_df['title'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# %%
title_df.sample(5)
# Out:
#                                                  title  title_len  \
# 846  here's what it's like to compete at the beijin...         92
# 627  submit the worst text you've gotten from your ...         54
# 283  jacob elordi has been living the dream filming...        120
# 851  2021 update on diversity, inclusion, and belon...         68
# 698  after years of singing the "the fresh prince o...        119
#
#                                            clean_title
# 846  here's like compete beijing winter olympics ac...
# 627                  submit worst text gotten landlord
# 283  jacob elordi living dream filming passionate l...
# 851  2021 update diversity, inclusion, belonging bu...
# 698  years singing "the fresh prince bel-air" theme...

# %%
clean_title_vals = title_df['clean_title'].values
print(clean_title_vals)
# Out:
# ['rauw alejandro celebrated valentine\'s day "muse" rosalía sweetest surprise'
#  '36 pieces trivia believe first'
#  'calling video game lovers, tell us favourite comfort video games'
#  '14 facts went head "how get away murder"'
#  '36 wild secrets people keeping spouses "could absolutely ruin" marriage'
#  'people poor students rich schools shared experiences, child feel like'
#  "rate creamy foods we'll guess age" 'zodiac sign reveal next book read'
#  'emma stone join club, andrew garfield lied "no way home"'
#  'jamie lee curtis explained #metoo would "really upset" mother janet leigh'
#  '"evil like memes" taking twitter, 18 best ones'
#  '22 things non-aussies hate australian lifestyle'
#  '35 things home even bobby berk would jealous found'
#  'people discuss unhealthy behaviors normalized, making question everything'
#  "23 dylan o'brien moments prove he's amazing screen"
#  'asked british people guess meaning 12 classic mexican pick-up lines'
#  'ton celebs joined forte "snl" last night, including kristen wiig willem dafoe'
#  '36 products add subtle personal touches home'
#  'martha stewart says break anthony hopkins separate hannibal lecter'
#  "tom hanks declined jeff bezos' space flight offer, reason make love tom hanks much"
#  "thanksgiving chocolate truffles, 'everything leftovers' seasoning, 50+ holiday trader joe's products try asap"
#  '15 times celebs quietly secretly slipped movie theater watch films fans'
#  '23 things ex-music students remember school'
#  '52 handy little products make say “go little rockstar”'
#  '27 splurge-worthy products black-owned businesses'
#  'evangeline lilly’s marvel colleagues appeared call faces backlash attending dc anti-vax rally'
#  '33 subtly sexist things women deal often go unnoticed'
#  'andrew garfield reason single brilliant scene "no way home"'
#  'think decipher countries descriptions residents?'
#  'many phrases actually consider gaslighting?'
#  'martha stewart criticized ina garten\'s covid tip reese witherspoon "more large cosmos"'
#  'eat dessert buffet like toddler birthday party i\'ll tell "bsc" character remind'
#  '5 completely mesmerizing black egot winners 7 chasing coveted title'
#  "women sharing embarrassing thing man said them, i'm flexible enough mental gymnastics"
#  'honor movie\'s 25th anniversary, here\'s cast "selena" vs.'
#  'anyone 28 relate hilariously depressing tiktok "torn" natalie imbruglia'
#  '"she told would rather eat tampon" — 42 brutal stories rejected asking someone'
#  'jason momoa zoë kravitz cute instagram exchange, two weeks jason lisa bonet announced split'
#  'want results, check 31 products impressive photos'
#  '42 products you’ll end using way often might think'
#  'aussies sharing common stereotypes foreigners actually believe australia'
#  "13 rules considered part unspoken social etiquette united states, i'm genuinely curious differ countries"
#  'timothée chalamet used youtube channel showed xbox 360 controllers'
#  'women sharing creepiest "nice guy" stories, need every man dates women read'
#  "identify beloved tv characters we'll reveal whether hail usa australia"
#  "apparently vegemite apricot jam tastes bomb together, put harm's way try"
#  '"yellowjackets" delivered wild (and deadly) season 1 finale, plus 11 tv moments week'
#  '"and like that" finale (kind of) featured samantha, plus 16 tv moments week'
#  '16 people job interviews bad, literally walked'
#  "scott disick lunch kris jenner filming kardashians' new reality show, amid reported drama kourtney kardashian's engagement"
#  "wish i'd always known 19 empowering facts old hollywood women"
#  '41 bestselling products may transform life'
#  'tell favorite foreign film netflix'
#  'dakota johnson asked allegations surrounding previous male co-stars: armie hammer, shia labeouf, johnny depp'
#  '29 actors effed big time shared major spoilers movies tv shows'
#  '45 american holidays absolutely get day'
#  'want help tasty research study? want hear you!'
#  '43 decorating tips make renters think "i wish i\'d known sooner"'
#  'people sharing paranormal thing ever happened them, reading can’t sleep'
#  'made version famous $100 rose bear way cheaper'
#  '22 huge celebs appeared cbeebies, mind blown information'
#  "here's 21 emo dudes whose songs scream-cried shower look like"
#  "cast rupaul's drag race: uk versus world spill 25 insider secrets season"
#  '35 affordable things make feel oh-so-fancy'
#  'here\'s know cast "trigger point"'
#  'dwayne "the rock" johnson wants daniel craig\'s james bond successor, hope producers seeing right'
#  "45 pictures make laugh uncontrollably matter many times i've seen"
#  'brenda song macaulay culkin engaged welcoming son last year'
#  'tom holland shared another tribute zendaya instagram, made history cfda fashion awards'
#  '16 coolest & swankiest college campuses us'
#  'miranda cosgrove revealed hole leg 2011 bus crash doctors explain'
#  "30 things '90s kids time makes zero sense today"
#  "know super curious, here's undeniable truth told coffee order"
#  'model linda evangelista got real rare side effects endured undergoing cosmetic surgery: "i look mirror"'
#  'know dream stay late'
#  "31 things must-haves others they'll probably must-have"
#  "best presidents' day home deals"
#  '34 off-beat (but still fashionable) finds make look like mastered cool kid aesthetic'
#  "24 celeb siblings can't even think one without mentioning other, looked like growing"
#  'money advice gotten boomers apply today?'
#  "wonho read internet's thirstiest tweets gave us peek abs"
#  '27 "encanto" behind-the-scenes facts specifically amazing songs'
#  'amy schumer got candid feelings motherhood sharing rare photo son gene'
#  "reveal encanto opinions we'll tell read next"
#  'melanie lynskey hit back body shamers brilliant, frame-worthy tweet'
#  '38 time-saving products people always thinking, “where day go”'
#  '14 thanksgiving fails even wish upon worst enemy'
#  'women sharing regret giving birth, even love children, incredibly nuanced'
#  '16 celebs turned huge roles later regretted'
#  '20 actors competed famous friends role'
#  'millennials able tick everything neopets quiz'
#  'holly madison recalled hugh hefner used "cult-like" rules, curfews, allowances keep "isolated" "gaslit" playboy mansion'
#  '22 self-care products parents want treat'
#  '33 skincare products wanna buy bulk reviews good'
#  '36 nail products anyone who’s sunk claws "euphoria"'
#  "women 30s sharing deep, heartbreaking, seriously real ways they've changed since 20s"
#  '26 genuinely iconic teen movie outfits, ranked cuteness'
#  '15 celebrities keep cosmetic surgery secret'
#  'would ever wear 20 raven baxter outfits real life?'
#  'people look things women like them, honestly messed'
#  '27 "encanto" scenes, lyrics, character designs actually cut final version film'
#  '32 celebs whose net worths think would high'
#  '17 delivery driver horror stories make want tip extra next time order something'
#  'home chef’s latest deal served: $110 first five orders'
#  'best deals target right'
#  '23 shocking tv moments wish could go back time see first time'
#  'spiritual abuse survivors sharing stories, heartbreaking reality talked enough'
#  '21 pregnant women whose halloween costumes made go, "damn, that"'
#  'women sharing toughest lesson learned years, expecting'
#  'charisma carpenter issued new statement support ray carter said joss whedon "tyrannical narcissistic boss"'
#  "25 subtle traits rich australian families growing '00s"
#  'rihanna thing matters right now, 11 celebrity pregnancy announcements broke internet'
#  'bradley cooper explained "licorice pizza" stopped "giving up" acting'
#  'stuff face nothing desserts, determine disney bird'
#  'apparently, women "and like that..." age "the golden girls"'
#  '30 products help upgrade wfh space year'
#  '15 things entitled customers signal servers tip well, annoying terrible'
#  'australians sharing favourite phrases make non-aussies say "what?" hilarious'
#  "35 bad parents zero excuses toxic things they've said done children years"
#  'side-by-side photos "pam & tommy" cast vs irl people played simply astounding'
#  'directors must really love 17 pairs actors together since keep getting cast costars'
#  'kanye west reportedly gave julia fox friends birkin bags birthday'
#  '43 moments season 2 "kenan" prove one funniest sitcoms air'
#  '"reba" first aired 20 years ago, here\'s cast looks like'
#  "dolly parton shared rare photo hot husband carl dean, suddenly i'm jolene take man"
#  "dax shephard got real like unclog kristen bell's clogged milk duct breastfeeding"
#  '18 "book love" behind-the-scenes photos make love movie even'
#  'married folks pointing miss single life, interesting perspective'
#  'billionaires rarely pay taxes — — 18 facts get angry'
#  'want results, check 31 products impressive photos'
#  '"nope" — jordan peele\'s newest horror film — first trailer, we\'re almost positive aliens'
#  'alana haim wants jonas brothers play haim biopic life'
#  'ariana grande\'s "miss creature" homage "black lagoon" proves reigning halloween queen'
#  '"she left behind fleas": people sharing stories housemates hell'
#  'bush dog animal never heard desperately need life'
#  '33 best things people learned therapy definitely read'
#  'kristen bell almost cut "gossip girl" and, xoxo, i\'m actually shocked'
#  'emma stone made rare public appearance husband dave mccary, continue absolute cutest'
#  '36 beauty products results inspire shake normal routine'
#  '36 quick problem-solving products people simply time deal'
#  'dakota johnson reflected "fifty shades grey" "pigeonhole" career, days costar jamie dornan said done "no harm"'
#  'would die "game thrones?"'
#  'recap: episode 5 "single\'s inferno" gets intense'
#  'people confessing "foodie words" can\'t stand, though write food living, agree'
#  '44 products satisfying before-and-after photos, might put trance'
#  "15 things get shop buzzfeed's last-chance sale"
#  '39 wildest moments ever happen teen drama'
#  't.j. osborne celebrated win cmas kissing boyfriend, first time same-sex kiss ever broadcasted awards'
#  'netflix announced they\'ve cast uncle iroh firelord ozai "avatar: last airbender" can\'t stop screaming excitement'
#  "here's everything know donovan carrillo — mexico's successful figure skater history"
#  'women tiktok thanking mom educating different shades breast milk — see doctor'
#  '20 excellent animated series fans "smiling friends" "vox machina"'
#  'movie songs know total giveaway age'
#  '36 pieces activewear cute might inspired work asap'
#  "bet can't get 10/10 tricky two truths lie quiz that's money"
#  "women sharing young first catcalled, i'm disgusted men"
#  '6 times samantha best "satc" movie 6 times miranda worst'
#  '30 products prove miracles happen believe'
#  '17 things seated restaurant, host judging hard'
#  '45 movie villains terrible, hate movies'
#  '42 problem-solving products chronically busy people'
#  'attention non-meat eaters — finally get impossible burgers australia'
#  '45 everyday things thought way cheaper actually buy'
#  'data — parents named babies 2021' '35 things $20 glad bought'
#  '16 iconic characters without important input actors played'
#  'ever set boundary loved one, boss, medical professional? tell us story'
#  '21 bone-chilling tv scenes prove actors play villain sooo well'
#  '22 funny relatable reactions "the woman house across street girl window"'
#  "17 snacks best trader joe's offerings tbh"
#  'matthew mcconaughey clarified stance vaccinating children covid-19, previously suggesting kids get shot'
#  'billie lourd got super honest generational trauma growing mom carrie fisher taught "what do" parent'
#  'want know movie couples think worst onscreen chemistry time'
#  '"jump in!" underrated disney classic — rewatch thoughts'
#  '12 times celebs called celebs 2021 far'
#  'lauren ridloff made history becoming first deaf actor play marvel superhero'
#  '21 famous men seriously deserve sexiest man alive because...well, pictures speak themselves, folks'
#  "31 food photos horrific, they'll hurt eyes even they'd destroy stomach"
#  "14 rihanna a$ap rocky's cutest couple fashion moments"
#  'aussies sharing thoughts british people rules need follow move australia'
#  "eat buffet can't afford we'll reveal introvert, extrovert, ambivert"
#  'a$ap rocky stopped show demanded fallen fans picked resurfaced video'
#  '20 television series soured fans second season'
#  '25 times customers proved absolute dumbest people earth'
#  '35 affordable things make feel oh-so-fancy'
#  '29 problem-solving products tired college student appreciate'
#  "23 small moments literally changed course someone's entire life"
#  '35 forgotten songs unlock memories aussie millennials'
#  '14 haunting real-life facts ever heard'
#  'became first latinx woman disability mt. kilimanjaro, proving "there nothing disabled person can\'t do"'
#  'kal penn cardi b’s wholesome twitter exchange led cardi offering officiate upcoming wedding'
#  '"definition please" movie tap vulnerable parts'
#  "coco pops 'mystery' flavour taste lollies"
#  '"abbott elementary" funniest tv show right now, 30 brilliant moments need persuasion'
#  'lived natural disaster, tell us, like?'
#  'billy porter called vogue featuring harry styles dresses skirts, nonbinary style "changed whole game"'
#  "millennial who's college gen z'ers teaching tiktok emojis really mean"
#  'charlie puth watch last night\'s episode "euphoria" "too real"'
#  'here\'s watch next absolutely obsessed "superman & lois" cast'
#  'sprouse twins cardi b, plus 33 famous people realize age'
#  '38 products guaranteed tackle cleaning issues currently googling'
#  "australian tiktoker documented american target like i'm extremely jealous australian one inferior"
#  '14 times "euphoria" great job depicting addiction'
#  'taylor swift pete davidson sang "three sad virgins" last night\'s "snl"'
#  "stan harry styles, choose pets we'll reveal iconic accessories"
#  '16 wholesome details tv movies show quite literally made love'
#  '21 subtle signs coworker — — actually toxic'
#  'penn badgley weighed wild finale "you" season 3, could store character'
#  'love "ratatouille," seeing 17 disney world details delight'
#  'made chick-fil-a chicken nuggets, honestly, better ever could'
#  'jamie lee curtis revealed lindsay lohan secret text code identify other, suddenly feeling like 2003'
#  '16 tropes horror films new "scream" unmasked'
#  'men confessing discovered girlfriend soulmate'
#  'major pop culture happenings week, celebrity tributes new trailers'
#  'kristin davis said she\'ll consider using "sex city" educate young kids whenever inevitably see'
#  'dylan o\'brien liked tweet seemingly confirming arden cho passed "teen wolf" movie huge pay cut'
#  '23 found footage movies loved "archive 81"'
#  'know exaaaaactly old based much like dislike cookies'
#  'much money could win "cash cab"?'
#  'whoopi goldberg suspended "the view" following comments holocaust'
#  "kanye west stepped venice alien-like mask face, guess good mine what's going"
#  '25 must-watch performances found bad movies'
#  '36 pieces activewear love wear gym'
#  'i\'m curious know "treat yourself" purchases live without'
#  'here\'s cast "dune" side side original 1984 cast'
#  'kirsten dunst revealed reason jesse plemons decided second child'
#  'princess mako japan gave royal title marry "commoner" fiancé, kei komuro, story deserves movie asap'
#  'pick tasty food eat meal, determine true superpower'
#  '17 celeb couples set celebs'
#  '15 eye-opening questions sex parties, answered people attend'
#  "here's tracee ellis ross 17 celebrities shared week #tbt"
#  'people calling "normal" things families actually toxic, aware'
#  '7 actors considered "ugly" role, 8 ugly enough'
#  'personality match mandalorian boba fett?'
#  'evan rachel wood says marilyn manson "essentially raped" filming music video 2007'
#  'taylor swift dressed squirrel halloween 2021 something nutty say'
#  'can\'t one literally laughing loud 17 lines "the woman house"'
#  '19 pop culture moments week truly destabilized core'
#  'tell us unprofessional way/reason ever fired'
#  "go luxury shoe shopping spree, we'll reveal celebrity style soulmate"
#  'people sharing things completely splurged 100% worth'
#  '17 people already halloween year'
#  '20 sci-fi novel adaptations even better book'
#  'really know famous people recognize celebrities walked street'
#  '15 shop buzzfeed stickers treat'
#  '17 haunted houses people periods would actually scared'
#  '24 disney movies messed enough small ways ruin'
#  'you’re planning fun night in, try 40 products'
#  'salma hayek told hilarious story angelina jolie slamming face birthday cake'
#  'people sharing they’ve walked first date, face hurts cringing hard'
#  'identical twin starts camming?'
#  '22 surprisingly fun sequels deserve love'
#  '57 things that’ll give home reno vibes without actual reno part'
#  "i'm begging freak guess generation based carb preferences"
#  '11 boyfriends epitome laziness, 11 boyfriends epitome caring'
#  '21 things publix workers absolutely hate 4 things absolutely love'
#  '50 tweets thoroughly shit australian lifestyle'
#  '27 deeply unsettling pictures make say, "wow, genuinely wish seen that"'
#  '13 best queer characters appear "degrassi"'
#  'what’s like never relationship?'
#  'andrew lloyd webber registered dog emotional support animal watching "cats" movie'
#  '24 problem-solving products may cost little extra *totally* worth'
#  'women sharing toughest lesson learned years, expecting'
#  '"euphoria" star jacob elordi spotted byron bay looking peak australian love see'
#  '15 celebrity couples unexpected still keep night'
#  "17 disney moments heartbreakingly real, i'm sure forgot making kids' films"
#  "lady gaga said there's one thing wishes she'd done differently planning 2017 super bowl halftime show"
#  'aussies trolling americans completely missing brief mullet'
#  '40 beauty products cheap people high standards'
#  'ever quit toxic job, tell us'
#  '11 tv movie couples whose chemistry good actors literally crushes'
#  "kanye west sent kim kardashian truck roses valentine's day, really want man give move"
#  'ben affleck jennifer lopez attended super bowl together pics everything'
#  '13 "don\'t look up" behind-the-scenes details need know watching movie'
#  '16 books black authors total must reads'
#  "buy 30 reviewer-loved products already, maybe i'll stop including many posts"
#  '15 comic books graphic novels make want read'
#  'aussies sharing social etiquette cues unique australian culture actually really interesting'
#  'prince harry meghan markle made statement "covid-19 misinformation" spotify neil young joni mitchell pulled music'
#  'jacob elordi living dream filming passionate love scenes sydney sweeney "euphoria," knows'
#  'laura coates reflected snubbed "jeopardy" producers alex trebek named potential successor: "i told \'no\'"'
#  'chocolate milk comes brown cows, 26 ridiculous conclusions kids came based flimsy evidence'
#  'telling discuss pay coworkers 18 red flags workplace'
#  '39 hard-working products anyone identifies little bit lazy need'
#  '14 stories women gave "nice guys" chance prove really, really deserve one'
#  '51 film tv scenes sexy heck without ounce sex'
#  '14 highly debated "pet rules" — genuinely need know many follow home'
#  "40 pettiest signs i've seen goddamn life"
#  '"gordon ramsay\'s method old, inaccurate folklore": people sharing cooking advice ignore costs'
#  'brenda song revealed details relationship macaulay culkin, thank god, i’ve dying know'
#  'i\'m laughing hard hilarious, creative, incredibly clever "not wordle, just..." tweets'
#  'jennifer coolidge said ariana grande\'s impression "jimmy fallon" got career "deadzone"'
#  'netflix dropped trailer "tall girl 2" spy new heartthrob obsessing'
#  'jessica chastain revealed conditions "scenes marriage" nude scenes oscar isaac'
#  'kristen stewart explained met fiancé dylan meyer gave nice details engagement party'
#  'people shared tv shows either nailed failed finales, ya know, points made'
#  'nicole kidman unveiled lucille ball "being ricardos" teaser trailer, wow, nailed'
#  'jennifer lopez said ben affleck less "open" relationship past tabloid treatment'
#  'bet can\'t recognise even 10 minor characters "brooklyn nine-nine"'
#  '22 photos saint lucia saying, "is place real?"'
#  'dakota johnson says grandmother tippy hedren\'s career "ruined" alfred hitchcock\'s alleged sexual assault'
#  'tom brady officially retires nfl, 22 unforgettable moments'
#  "zendaya tom holland's adorable instagram interaction sending frenzy, imagine i'll react they're actually red carpet together"
#  '"my dad pays fine every negative comment body": people sharing toxic reasons set boundaries loved ones'
#  'people sharing worst job interview horror stories, red flags everywhere'
#  "what's nightmare period story?"
#  '43 "gifts" buy actually super practical'
#  'kate beckinsale revealed go hospital hurting putting leggings'
#  'here\'s seen cast "hawkeye"'
#  '50 products before-and-after photos prove remarkable'
#  'here\'s update memorable "antm" contestants'
#  "former victoria's secret angel erin heatherton admits turned dangerous medications stay skinny"
#  'mindy kaling wants kids\' "consent" sharing pics social media'
#  '18 pieces home decor amazon, little secret'
#  'tell us tv show reboot storylines never happened (like ever)'
#  "20 behind-the-scenes facts spike lee's career fascinate inspire"
#  'random questions reveal floss'
#  'olivia jade says lives fear "canceled again" following college admissions scandal'
#  "people who've experienced burnout, what's warning sign wish picked sooner?"
#  '17 famous people hated working marvel much, either quit really, really wanted'
#  '16 olympian couples competing winter games'
#  "sarah jessica parker finally said something carrie call 911 big's heart attack"
#  'shay mitchell proved master illusions hid pregnancy'
#  '17 times celebrities tore every single rule book red carpet'
#  'classic aussie pub foods would save?'
#  'answers predict horror icon murder' '32 things care love wine'
#  '17 easy effective head-to-toe skincare tips soft, hydrated skin winter'
#  '15 photos restaurant workers give wild behind scenes look really goes kitchens'
#  'know time break friends'
#  'jamie foxx said plan getting married anytime soon'
#  'people sharing subtle signs job toxic, yikes, hope workplace like'
#  'want hear impossible coincidence actually happened'
#  'never taught school: murder civil rights activist leon jordan attempts cover truth'
#  'sebastian stan revealed — wait — stashed steel balls pants get character "pam & tommy"'
#  'mike wazowski favourite "monsters, inc" character, scenes tell'
#  '15 books want read loved hbo\'s "insecure"' 'film "passing" seen cast'
#  '37 products buy help lift spirits winter'
#  'naples, reykjavik, popular destinations around world travelers "love-hate relationship"'
#  'aussies noticing major decline christmas beetle numbers actually super concerning'
#  'dakota johnson revealed that, set “the social network”, andrew garfield nice, jesse eisenberg ignored existence'
#  'guide social media profiles cast "all us dead"'
#  'pete davidson admitted he\'s sure "how" boil water know think'
#  '13 tv movie writers came clean moments scripts regret'
#  "104 romantic they'll give heart eyes"
#  "27 stories people discovered mom dad's infidelity left speechless"
#  '"succession" star sarah snook secretly got married almost year ago, ceremony, thankfully, nothing like shiv\'s'
#  '34 hysterical tweets month far need see'
#  'many macabre movies watched lifetime?'
#  'telling discuss pay coworkers 18 red flags workplace'
#  'adorable pet moments warm soul forever'
#  'kristen stewart said "speechless humbled" oscar nom "spencer," fiancée rooting cutest thing ever'
#  'people sharing things helped get better work-life balance, refreshing'
#  '45 movie villains terrible, hate movies'
#  'person going viral roasting people visit popular cities, funny follow someone social media like'
#  '30 style moments "the marvelous mrs. maisel" prove miriam going'
#  'true "friends" fans remember little details – one them?'
#  'hello, saw "dune" officially timothée chalamet hot bandwagon'
#  "thoughts buzzfeed shopping content, we'd love hear"
#  'i\'m genuinely curious "normal" opinions pandemic 32 questions'
#  '29 beauty products "low-maintenance" reviewers rave'
#  "here's eric nam would rank songs"
#  'cook home nearly every day, small-but-mighty tips really helped kitchen'
#  'native american chief, anne frank, 15 costumes absolutely steer clear halloween'
#  '21 celebrity couples made marriages work 20 years 15 make first year'
#  '"make pockets hurt" — woman\'s take women pay 50/50 dates actually makes lot sense'
#  "charlie day read x-rated thirst tweets get us mood valentine's day"
#  'seen 18/34 episodes, obsessed television halloween'
#  "bet can't get 10/10 tricky two truths lie quiz that's money"
#  'save one: ultimate aussie food edition'
#  'black women, tell us favorite protective styles natural hair'
#  '32 products fitness-related aches pains'
#  '24 jobs people claim total asshole would'
#  "watch seth rogen paul rudd take increasingly strange trips memory lane new super bowl ad lay's"
#  'alicia silverstone says got banned dating app twice thought profile fake'
#  'there\'s "twin peaks" resident us all, one you?'
#  '17 best toys gifts indigo kid life'
#  '36 products make household run seamlessly'
#  '38 little home products make feel warm fuzzy inside'
#  'evangeline lilly wrote lengthy anti-vaccination instagram post attending anti-mandate rally dc'
#  '"breakfast construct" 20 food opinions people believe whole chest'
#  "28 products people who've used accutane swear"
#  '21 hard-hitting moments "all us dead"'
#  "eat massive meal we'll accurately guess zodiac sign"
#  'robert pattinson explaining pretended work preparing play batman sincerely funny'
#  "people sharing one food gives away from, bet can't get right"
#  'major pop culture happenings week, celebrity tributes new trailers'
#  'robert pattinson shared even agents shocked wanted play batman'
#  'melanie lynskey shared "really important" "yellowjackets" character comment body revealing production team member suggested get personal trainer'
#  "went queer alcoholics anonymous meeting sober 30 days, here's learned"
#  'disney taking "different approach" "snow white" peter dinklage\'s impact'
#  '14 quotes "schitt\'s creek" character tells us'
#  'werewolves hostages abandoned bank vault, 35 wild parts "teen wolf"'
#  'teach school: assassination medgar evers murderer walked free three decades'
#  "here's australians react spot kangaroo front yard"
#  '37 cleaning products reviewer confirm work like "magic"'
#  'relationship stereotypes people cannot handle anymore'
#  "i'm bit french fry aficionado, ranked fast-food fries i've ever"
#  '“the size body least interesting thing you” said intuitive eating dietitian tiktok'
#  '14 horrible bosses probably faked way top'
#  'these19 mind-blowing easter eggs stephen king adaptations show deep things connect'
#  '18 celebrity instagrams probably missed last week'
#  '28 home decor products need that’ll instantly refresh space'
#  'here\'s cast "dune" characters playing'
#  '9 "bel-air" cast members new show vs. irl vs. original "fresh prince bel-air" cast'
#  '34 nice things home'
#  "today years old realized first cousins removed refers cousin's child, i'm alone"
#  '32 products make home feel five-star-hotel clean'
#  "24 subscription valentine's day gifts anyone loves food"
#  'people sharing random bits life advice wholesome'
#  'heard sebastian stan\'s talking penis "pam & tommy" yet, here\'s tea'
#  '"rich friend" grew 16/36 things house'
#  '"got" fan, well realized "eternals" premiere brought richard madden kit harrington place time'
#  'ariana debose\'s "snl" monologue musical double act kate mckinnon'
#  'chance rapper said he\'s experienced "a lot dark days" dealing ptsd'
#  'hailey bieber says "extremely difficult" dealing justin bieber\'s sobriety journey'
#  'adele revealed new album includes voicemail left friend experiencing anxiety attack divorce'
#  '"jeopardy" questions easiest show\'s history. bet get right.'
#  'stairs lead nowhere, 17 photos sit right'
#  'kristen bell revealed dax shepard helped mouth breastfeeding'
#  'series instagram posts shared sunday morning, kanye west claimed kim kardashian accused "stealing," "being drugs," "putting hit her"'
#  'carole baskin "tiger king" revealed thinks happened missing husband reddit ama'
#  'florence pugh explained us dressing "black widow" character halloween, argument checks'
#  '33 times casting directors chose people looked similar could related real life'
#  '35 products stop putting buzzfeed shopping posts, simply deserve'
#  'halle berry approved saweetie\'s "catwoman" halloween costume see'
#  '42 products anyone whose house could *always* cleaner'
#  'here\'s watch can\'t get enough cast "this us"'
#  'tell us guilty habits test people correctly guess star sign'
#  "trendiest foods past year i'm curious even tried bite"
#  'ed sheeran says thought gay "for bit" kid'
#  '14 things never ever want swallow unless trying go er'
#  '"romy michele" musical star says fired pregnant right show supposed hit broadway'
#  "everyone controversial cooking opinion two, i'm dying hear"
#  'sure, probably tried 13/40 chocolate foods, highly doubt tried 27/40'
#  'gigi hadid zayn malik reportedly split zayn issued statement regarding alleged incident yolanda hadid'
#  '"gossip girl" reboot teachers, plus 17 worst tv teachers ever'
#  'name iconic horror movie slashers based one clue?'
#  "take trip mexico we'll guess love language"
#  "here's anya taylor-joy jell-o wrestling tigger onesie emmy awards"
#  '16 entitled "nice guys" need realize "no" complete sentence'
#  '21 superhero movies could stand test time' 'film "passing" seen cast'
#  'finneas revealed embarrassed front taylor swift actually'
#  '17 times musicians decent human beings actually stopped shows protect fans'
#  '16 times "boss babes" mlms took things way, way far'
#  'kate hudson sang ariana grande\'s "7 rings" everyone wants make album'
#  'eve shared photo baby bump announced pregnant first baby'
#  '22 food products we’ve tried absolutely loved'
#  'kylie jenner welcomed birth second child travis scott revealed news instagram'
#  'adele says doesn’t want major tour behind “30” people might reminded covid-19 listen music'
#  '11 reasons fall love "book love"'
#  'bella hadid first person family go therapy, says "domino effect"'
#  'celebs "thats name" trend tiktok, i\'m confused'
#  'bob odenkirk revealed like heart attack set "better call saul"'
#  'lena dunham explained "girls" reboot happening time soon'
#  'non-americans sharing american things wish common live'
#  "eat way quiz we'll tell fall love year"
#  'amber rose said previous 2015 comments kardashians "immature"'
#  'julia fox confirmed broke kanye west, deleting photos instagram'
#  'julia garner responded "anna delvey\'s" statement "inventing anna" said expect watch show'
#  '27 products before-and-after photos kinda gross, also really satisfying'
#  'everything air episode 6 "single\'s inferno"'
#  '21 "eternals" red carpet moments prove cast ready take marvel cinematic universe'
#  '27 famous actors freaking talented get credit deserve'
#  "might last olympics leslie jones's hilarious coverage nbc allegedly pressuring stop"
#  'peyton manning supposed talk nfl playoffs "snl," gushed "emily paris" instead'
#  'months mgk travis barker got matching tattoos album name, mgk decided change'
#  'men sharing annoying thing guy, answers honestly place'
#  'meghan trainor spilled biggest parenting fail super easy mistake make'
#  'a24 released mind-boggling trailer alex garland\'s next film, "men"'
#  'here\'s 12 "insecure" cast members looked like first episode compared'
#  '15 books featuring noteworthy disabled leads'
#  '35 products $100 upgrade home decor'
#  '21 hilarious bumper stickers guaranteed spice back minivan'
#  "women sharing used life hacks, bet i'm taking notes"
#  '"penn badgley hot joe goldberg not" 26 great tweets describing wild "you" season 3'
#  "downton abbey's michelle dockery got engaged fiancé famous sister"
#  '15 things shop buzzfeed that’ll make fun additions home'
#  "people saying changing voicemail could save life lost — they're wrong here's instead"
#  'brian cox says turned role “pirates caribbean”'
#  "people sharing wholesome moments they've ever stranger, stories make day"
#  'ranked 32 movie tv wedding dresses much would never ever wear'
#  'adele recalled feeling ashamed divorce simon konecki: "you feel like good job"'
#  "answer 8 questions money personality we'll give saving tip"
#  'love john mulaney olivia munn\'s baby "naps like spider-man"'
#  '45 products good — like tom brady — never want retire'
#  '19 times people dealt absolute worst landlord ever'
#  "38 absolutely wild things can't actually believe happened teen dramas"
#  '15 times steve harvey absolutely lost "family feud" answers'
#  "hotel cleaners sharing wildest disturbing things they've clean up, one ever deal much poop"
#  'assigned disney character zodiac signs bet never guess made list'
#  'true crime: everything need know unsolved murder harry harriette moore'
#  'language quiz reveal whether australia usa'
#  'two months ago, switched one thing skincare routine — skin never looked glowier'
#  '21 "all american" moments prove spencer olivia always meant'
#  '35 cleaning products people look toilet gag'
#  'julia fox says dating kanye west "fame" "clout" "couldn\'t care" people think relationship'
#  'andrew garfield, master consistent denial, said misses pretending "spider-man: way home"'
#  '"you" season 3 dropped everyone thirsting theo engler'
#  'people see blue perfectly well read words'
#  "we've always seen outside, here's inside 17 iconic landmarks looks like"
#  'people sharing exactly caught significant cheating, extremely eye-opening'
#  'liked netflix\'s "the tinder swindler," love scammer tv shows, movies, books, even podcasts'
#  '25 products disgusting-yet-satisfying photos hate love see'
#  'jennifer lopez called hoda kotb live tv valid points made'
#  '25 "facts" everyone agrees true are...wait minute...completely false'
#  'rachel lindsay says got "death threats" explosive interview former "bachelor" host chris harrison'
#  'taylor swift revealed new music video "i bet think me" directed blake lively'
#  'khloé kardashian said true wants dress "pua pig" might'
#  '19 fun facts help get know "euphoria" actor sydney sweeney'
#  'want feel *little* bit like grown-up, try 45 products'
#  '35 "new girl" jokes, 33 "friends" jokes, 32 "the office" jokes hilarious'
#  '31 looks prove rihanna queen bold style'
#  "ummm, hard, choose one chocolate dessert i'll predict date valentine's day"
#  'kristen stewart beyoncé, kirsten dunst more, 2022 oscar noms full exciting firsts'
#  '18 brother-in-law sister-in-law horror stories sound like literal nightmares'
#  'courteney cox neve campbell talked reprising roles new "scream" movie, i\'m clutching phone anticipation'
#  'treated differently work disability?'
#  'woman gone viral tiktok showing hypocrisy sex ed taught young girls'
#  'justin bieber pretended confront charlie puth facetime peak awkwardness'
#  '27 disney moments people say make sad-cry happy-cry'
#  'dwayne "the rock" johnson praised joe rogan\'s statement addressing neil young joni mitchell leaving spotify'
#  'binging "cowboy bebop" episode rankings came'
#  '19 horrible parent-teacher interactions prove teachers get paid enough'
#  "23 hysterically weird things people saw friends' houses friends thought normal"
#  "pretend kid we'll tell pet perfect"
#  '22 pairs leather pants wardrobe needs punk pick-me-up'
#  '24 tattoos actually bigggg red flags'
#  'wake "the great resignation", aussies sharing reasons they\'ve left jobs'
#  "today years old learned women's life hacks, i'm sharing"
#  '25 times harry styles went way make fans hella happy concerts 2021'
#  'people play wordle every day able unscramble 5-letter words 1 minute less'
#  '38 kitchen products make cooking 2022 much easier'
#  'people calling celebrities suspect faking personalities camera, fascinating'
#  '27 stylish home decor things amazon canada aren’t throw pillows candles'
#  'people sharing popular "disgusting" things everyone stop doing, points made'
#  'order school lunch find old mentally'
#  '19 adorable instagram posts make love zendaya even'
#  'feel superior single-use plastic friends 36 reusable products'
#  '48 problem-solving products make "i\'ll later" list way easier'
#  '15 people tried change partners, case needed reminder toxic mindset'
#  'tell us "twilight" opinions we\'ll reveal berry matches energy'
#  'joe alwyn gave us rare peek relationship taylor swift'
#  'hugh jackman showed fans accidentally "sliced" nose practicing "the music man"'
#  'zendaya defended "euphoria" anti-drug group said show glorified drug use'
#  'jacob elordi living dream filming passionate love scenes sydney sweeney "euphoria," knows'
#  '57 behind-the-scenes facts teen shows think neat'
#  'thandiwe newton dragged sean penn made (ignorant) comments masculinity'
#  'make sandwich using contents fridge unlock true color aura'
#  '38 shocking photos iconic places vs. planet warms 3 degrees celsius'
#  "put ranch 13 foods, i'm sorry, gross"
#  'pete davidson machine gun kelly kid cudi, celebs kanye mentioned called weekend'
#  '17 historical events people taught school, definitely know'
#  'sounds like idris elba would gladly play james bond role offered him, happened yet'
#  'uncle proved tackle conversations race kids going viral explaining martin luther king jr. nephew'
#  '20 video game movies made feel like wasted time'
#  '15 black asmr accounts need youtube playlist right away'
#  'ferrell says turned $29 million "elf" sequel'
#  'apparently cast "all us dead" lots fun shooting bts moments prove'
#  '20 forgotten movies disney catalog' 'here\'s seen cast "locke & key"'
#  'let\'s see match 30 quotes right "scream" movie'
#  '21 celebrities dated married on-screen siblings, uncles, parents'
#  '44 thoughts watching "the sky everywhere"'
#  '38 celebrities thrown smack wwe' '18 posts straight alternate dimension'
#  "worked peloton app two weeks — here's liked like"
#  'britney spears walked back comments jamie lynn “scum,” added “obviously hurt”'
#  '16 husbands whose hysterical fails left very, embarrassed'
#  'nicola yoon, j.elle, share thoughts black love joyful books necessary'
#  'misconceptions open relationships?'
#  "doctors replace half woman's tongue thigh muscle, results mind blowing"
#  'khloé kardashian commented instagram post claiming dating former netflix reality tv star: "not true"'
#  '28 powerful cleaning products that’ll make easier keep home tip-top shape'
#  'sophia bush talks healing "one tree hill" trauma podcast, "good sam" special,'
#  'megan fox full-on straddled machine gun kelly la concert, thereby turning pda 11'
#  "here's recap latest celeb news — good, sad, funny"
#  "tell us perfect day we'll guess next side hustle"
#  'networking jobs, purpose, 15 adult problems one prepares'
#  '"the mentalist" actor simon baker reportedly broken designer laura may gibbs attended anti-vax rally'
#  '35 home products $50 make space look bit polished'
#  'honestly feel sorry 18 people really, really bad week'
#  "roundup 25 things celebs week — 'em fantastic 'em definitely"
#  'reese witherspoon says "legally blonde" rejected filming stanford university'
#  "17 emma chamberlain's best tiktok moments deleted app i'm sad"
#  '17 wild times "regular" people realize met celebrities'
#  'ranked 15 "hunger games" costumes "cinna would never approve" "girl fire"'
#  "12 sitcom characters who'd excel pandemic, 14 who'd handle alright, 12 who...wouldn't well"
#  "kendall jenner took photos snow wearing string bikini fur boots, i'm freezing looking"
#  '33 actors probably realize working almost decade (or longer) already'
#  "twitter currently predicting scott disick's reaction kourtney kardashian travis barker engagement news, i'm ngl, they're spot"
#  "nbc confused mickey guyton jhené aiko's name super bowl right performed"
#  'tell us celebrities earned respect'
#  'tell us popular movie costars date real life, 100%'
#  'yikes, 19 people got roasted bad honestly need delete accounts'
#  '"eternals" introduced new character mid-credits scene — here\'s we\'re freaking'
#  '20 common business practices quite unethical, used often'
#  "tell us usual mcdonald's order we'll guess introvert extrovert"
#  '33 cheap home products lazy people need know'
#  'finneas revealed embarrassed front taylor swift actually'
#  '17 things probably wrong, life hacks fix'
#  '44 problem-solving products that’ll make jump joy well work'
#  'harry sally? john mclaine holly? quiz determine iconic holiday couple'
#  '28 serial killer facts true crime fans find shocking'
#  "26 stories seemingly insignificant events changing someone's entire life"
#  'top 5 digital marketing strategies worked tesla'
#  '34 beauty products anyone whose routine 10 minutes less'
#  'aussies sharing foreigners need know australia super insightful'
#  "endless scooby-doo impression, detour ex's house, 23 ways men absolutely ruined first dates"
#  '14 "encanto" behind-the-scenes stories recording "surface pressure" luisa much jessica darrow'
#  'took pug "most dog-friendly" hotel us, collective thoughts'
#  '34 products $15 jaw-dropping photos'
#  'people used wealthy anymore sharing things learned poor, happens often think'
#  'tefi pessoa joked wearing dress incorrectly uk premiere "dune"'
#  'submit worst text gotten landlord'
#  "17 actors i'm convinced could play role"
#  'australian women sharing stories approached men public places making blood boil'
#  "34 celebrities really popular 2002 much they've changed since"
#  'former "nice guys" shared made change ways, need men date women read asap'
#  '21 tweets wordle honestly good playing game'
#  '50 best hbo teen characters time, ranked'
#  "travis barker's son posted tiktok dad kourtney kardashian's engagement dinner, feels like actually there???"
#  'here\'s first look "the time traveler\'s wife" adaptation coming spring hbo'
#  'amanda seyfried says "tough case covid" right getting oscar nomination "mank"'
#  "teachers revealing worst things students' parents ever said them, i'm deeply disturbed"
#  'matthew macfadyen thank iconic hand flex "pride & prejudice"'
#  '51 products whose designers truly visionaries time'
#  '15 "influencers" absolutely zero respect sellers businesses reached'
#  'adele recalled feeling ashamed divorce simon konecki: "you feel like good job"'
#  'channing tatum stopped watching marvel movies "traumatized" "gambit" film got canceled'
#  '30 things help prevent mess taking home'
#  'jason sudeikis looked back day allowed olivia wilde ellen degeneres cut hair tv'
#  '20 high fashion dogs dress better'
#  "steve irwin's son robert chased nearly attacked 12-foot crocodile, video truly wild"
#  'kelsea ballerini shared struggle bulimia teenager'
#  'every kill "scream" franchise, ranked'
#  '"never turn opportunity pet animal": 14 people revealing best life advice grandparents told'
#  '[poll] picking best movies biggest directors'
#  'disney world architects embedded hidden easter egg park idea'
#  'people included dogs weddings sweetest ways'
#  '16 wholesome details tv movies show quite literally made love'
#  'lily collins defended "emily paris" acknowledged emily seems "annoying"'
#  "21 celebrities appeared significant other's movies tv shows"
#  "kylie jenner got top floral arrangement travis scott valentine's day"
#  'director "queen damned" says cher almost cast instead aaliyah'
#  'emma watson looked like actual angel making return red carpet'
#  "people who've nudes leaked sharing stories, they're upsetting"
#  'jodie turner-smith opened breastfeeding journey motherhood: "cheers mummas — especially black mamas"'
#  '50 funniest quotes "what shadows"'
#  '32 "euphoria" high tweets laugh school walking violation'
#  'mariano\'s walk "encanto" tiktok trend — 25 best ones'
#  "celeb stylist law roach's clients going best part 2022 awards season, 23 past looks prove"
#  'nurse explained "no beds" actually means comes covid-19, everybody needs see'
#  'true crime: everything need know unsolved murder malcolm x'
#  '20 reasons olivia colman queen hearts'
#  'old clip priyanka chopra saying "expecting" nick jonas resurfaced announced baby news'
#  'marvel working kathryn hahn "wandavision" spinoff series, yes, greatest day ever'
#  '"you need medication depression" 18 toxic positivity "tips" people received loved ones'
#  "people who've nudes leaked sharing stories, they're upsetting"
#  'clean things often, home gross'
#  'porn site went viral tiktok showcasing conversations around consent filming'
#  'woodworkers get credit deserve, 25 photos prove'
#  'kim kardashian poked fun three divorces (and weddings) wedding toast'
#  'adele responded rich paul engagement rumors ring brit awards sparked flurry questions'
#  '19 "squid game" behind-the-scenes facts super interesting'
#  'gwyneth paltrow revealed talks kids sex informative af'
#  '34 cleaning products get job done first damn time'
#  '15 abortion stories actual women prove safe easy access everything'
#  'soup opinions reveal best quality'
#  'steve "blue\'s clues" joined tiktok, hilariously, first video millennial'
#  '50 best "parks recreation" quotes time'
#  '21 romantic comedies people hate romcoms'
#  "19 nostalgic things people miss '90s"
#  "angelina jolie's kids grown yes, old"
#  '17 books tackle aromantic asexual validation'
#  "tell us witch opinions we'll reveal mystical witchy read pick next"
#  'gigi hadid says used avoid "real housewives" cameras yolanda hadid show'
#  'turns actually "coregasm" ab exercises, excuse million crunches'
#  'olympian showed swag gotten beijing far, worth thousands dollars'
#  "actors age, save one life's work"
#  'jay-z beyoncé dancing super bowl halftime show energy need year'
#  'questions "squid game" season two need answer?'
#  "i'm applauding 18 famous women called hollywood way depicts women screen"
#  '14 people told us student loan debt would change lives, important conversation'
#  'breakfast questions predict chance crush'
#  'years singing "the fresh prince bel-air" theme tune repeat, watched first episode "bel-air"'
#  "adele arrived brit awards truly awe-inspiring gown ring, i'm shaking thinking potential engagement announcement"
#  'physical therapist sharing doable tips tricks dealing back pain posture working remotely'
#  'could make across survive glass bridge "squid game?"'
#  'miles teller said he\'s vaccinated covid-19 "a while" taylor swift fans questioned vax status'
#  'know difference medical emergency truths & myths'
#  'channing tatum revealed almost quit acting 2018, makes lot sense'
#  "details coming british baker caught using illegal american sprinkles, can't stop laughing entire saga"
#  '19 red carpet outfits repeated recycled something totally new'
#  'aussies sharing experiences overseas changed view australia responses fascinating'
#  "40 beauty products readers can't get enough"
#  '"just hay fever": 19 tiktok sounds millennials maybe gen z\'ers recognize'
#  "teens using lube primer, talked dermatologist – spoiler alert – it'll clog pores give acne"
#  "people sharing b.s. survival myths could actually get killed, i'm thankful read"
#  '42 baby products new parents might want invest'
#  '15 celebrities use stage names, like 30% people know real names'
#  'robert pattinson confessed nervous audition "twilight" agent suggested take valium'
#  '21 "encanto" products bring even disney magic life'
#  '24 products make say "i understand buzzfeed always writes these"'
#  "here's recap latest celeb news — good, sad, funny"
#  '23 teachers cracked class students funny good'
#  'people tried "fix" someone relationship, want hear story'
#  '36 things wear sure going snow rain' '34 products give second glance'
#  'eat way day find "euphoria" girl personality embodies soul'
#  'nick cannon says he\'s always insecure "skinny" body usually "hides covers" sex'
#  '15 best quizzes february 2022 far'
#  "i'm sorry, literally 40 things growing up, congratulations! officially old"
#  '"this us" featured jack sadly dealing mom\'s death, plus 14 tv moments week'
#  "aussies disgusted melbourne cafe's behaviour offered free rats customers spent $160"
#  '16 college dorm horror stories prove never become ra'
#  'people sharing things helped get better work-life balance, refreshing'
#  '48 stylish things need planning escape cold winter heat'
#  'in-depth personality quiz reveal whether right left brain dominant'
#  'amazon canada releasing epic daily deals month feels like black friday came early'
#  '90s rom-coms 100% make life better'
#  'lady gaga fans defending accent "house gucci" film’s dialect coach criticized'
#  '19 things lesbians sick tired straight people'
#  "can't pass australian l-plates driving test, surrender licence asap"
#  '13 weird food combinations actually really, really good'
#  'film tv crews, want hear working conditions set'
#  "cheryl hines tweeted statement condemning husband robert f. kennedy jr.'s remarks vaccines holocaust"
#  '36 unusual pet friendships could break internet'
#  'new kanye west documentary reportedly delves mental health struggles: "i would still moments felt like, suicidal"'
#  'video channing tatum playing puppies talking rehearsing "magic mike" pure gold'
#  'netflix released "bridgerton" season 2 first look photos, march 25 can\'t come fast enough'
#  'latina character dropped neil patrick harris\' new netflix show "hurtful derogatory"'
#  'food customs purely australian rest world too?'
#  "here's support partner, friend, loved one chronic pain, according living"
#  'turned away lounge "not dressing gender," person ready discrimination end'
#  'emma thompson opened intense prep naked scene upcoming film'
#  'zendaya wore bold gold breastplate red carpet, cannot stop thinking'
#  'christina aguilera supported britney spears new interview snubbing red carpet two months ago'
#  "female ride-share driver, we'd like hear experiences"
#  '15 times "ted lasso" explored reality mental health'
#  '33 gadgets buy baby arrives'
#  '25 stylish yet affordable things boohoo you’ll probably want wear time'
#  '"breakfast construct" 20 food opinions people believe whole chest'
#  'kirsten dunst jesse plemons oscar-nominated power couple work "the power dog"'
#  '38 skincare tips always true matter old'
#  'aussies raging fucked state property market painfully relatable'
#  'people tried 7/26 sweet, impress me, tried least 14/26'
#  '18 outfits chandler, joey, ross wore "friends" human wear'
#  '10 years ago world blessed "girls" hbo'
#  '22 signs restaurant might serious tourist trap (and find great, local spots instead)'
#  'people retelling scariest things saw firsthand, honestly prepared'
#  'famous voices behind characters "big mouth"'
#  '71 brilliant details "community" emmy "best attention detail comedy series"'
#  '36 products might help solve sleep woes'
#  '26 things people said children mind-blowing, astonishing, 100% fake'
#  'clean things often, home gross'
#  'people shared 30 things worth money anymore, really insightful'
#  '19 stars attended school together working together'
#  'people true clean freaks everything list'
#  'adele talked body objectified response following viral birthday photo'
#  'going theme parks, wearing regular clothes everyday, 20 pre-pandemic habits want know still'
#  '"never turn opportunity pet animal": 14 people revealing best life advice grandparents told'
#  "people sharing pettiest responses people involved mlm's, love mess"
#  '"west side story" star rachel zegler addressed ansel elgort allegations'
#  "i'm sorry tell — parents — owned even 20 things growing up, rich friend"
#  '7 actors considered "ugly" role, 8 ugly enough'
#  'people sharing "dirty little secrets" they\'ve never told anyone range wild seriously hilarious'
#  'emma roberts spoke headspace amid reports garrett hedlund broke up: "i like ever have"'
#  "people many thoughts critiques kendall jenner wearing dress someone else's wedding"
#  'tell us time put medical care cost'
#  'people practice polyamory — rules put place relationships?'
#  'eat dessert buffet like toddler birthday party i\'ll tell "bsc" character remind'
#  'taylor lautner recreated meme-worthy "where hell been, loca?" jimmy fallon, hilarious think'
#  "27 weird '90s cult movies worth time"
#  'watched enough tv tell tv shows spinoffs?'
#  'nick cannon said "salutes" kanye west\'s attempts get kim kardashian back, released song ex-wife mariah carey'
#  'machine gun kelly said megan fox\'s engagement ring thorns "if tries take off, hurts"'
#  '19 tv shows movies know filmed australia'
#  'heard 15/18 underrated gems bts true army!'
#  '27 things learned dylan minnette, audition process "scream" hardest "13 reasons why" scenes shoot'
#  '16 times "boss babes" mlms took things way, way far'
#  "mr. feeny posting workouts online, 94 i'm thoroughly impressed"
#  '19 karens entitled, retail workers never, ever forget'
#  '37 "australians like" tweets make laugh, say "saur troo"'
#  'kristen stewart said wearing replica princess diana\'s wedding dress felt like "spooky day"'
#  'kylie jenner travis scott named son “wolf”'
#  'brian cox says turned role “pirates caribbean”'
#  'ton celebs joined forte "snl" last night, including kristen wiig willem dafoe'
#  'nicola coughlan got candid overwhelmed people sending messages body, really uncomfortable people think ok'
#  'aussies sharing experiences overseas changed view australia responses fascinating'
#  '14 times detective rosa diaz "brooklyn nine-nine" bisexual legend'
#  "19 surprisingly fun facts never knew actor jenna ortega's life"
#  'struggle acne, tell us products worked best far'
#  'alan cumming says suicidal right landed role "goldeneye"'
#  'mindy kaling dressed issa rae, elle woods, ali wong female comedy icons halloween'
#  'week 17 people killed bronx fire, cardi b pledged donation families'
#  "aussies raging sky-rocketing price groceries thank god i'm one"
#  'ryan reynolds sent hugh jackman charcoal drawing face opening night "the music man"'
#  'wanna know dominant personality trait? eat ice cream find'
#  'lily james said lot women "relate" scrutiny pamela anderson faces "pam & tommy"'
#  "50 facts every us state, there's strong chance state interesting one"
#  '40 things deserve don’t already'
#  'get 10/14 lyric quiz adele’s "easy me," probably need hug'
#  "we'll tell soulmate's initial based preference instant noodles"
#  '"euphoria" star eric dane opened cal jacobs\' "epic, dumpster fire" meltdown using prosthetic penis'
#  'watched "scream" first time, many questions'
#  '19 songs would tiktok famous released today'
#  '13 celebrities made big bought parents brand-new house'
#  'closet disaster zone, 34 organization products help'
#  'try tell many celebs first trailer "don\'t look up," believe — watch'
#  'i\'ve never seen "the vampire diaries," ranked characters based names pictures'
#  'here\'s kristen bell hated filming "the woman house across street girl window" scene, along bunch behind-the-scenes secrets'
#  'here\'s update fave couple "too hot handle" season 3'
#  'simply understand people watching "dickinson"'
#  'joe rogan addressed spotify controversy neil young, meghan markle, prince harry, others spoke covid misinformation podcast'
#  '34 inexpensive things look way expensive price'
#  "used kneeling ergonomic chair 30 days here's need know"
#  'whoopi goldberg refused wear fake jewels "cinderella," plus 12 actors demanded costume changes'
#  "former employees anonymously sharing company secrets, tea, y'all"
#  '15 times famous men called body standards hollywood'
#  "25 people revealed silently judge others — let's see agree"
#  '35 "new girl" jokes, 33 "friends" jokes, 32 "the office" jokes hilarious'
#  'lin-manuel miranda sang "encanto" star jessica darrow perfect "hamilton" lyrics recorded "surface pressure"'
#  "couples therapists sharing common toxic signs usually indicate relationship work out, i'm taking notes"
#  'news first pregnancy leaked, drew barrymore recalled feeling "depressed" robbed privacy'
#  '20 wild, lavish, weirdly specific things rich bosses asked employees get'
#  'aussies sharing brutally honest thoughts americans ooft, things get heated'
#  'rosario dawson senator cory booker reportedly broken two years couple'
#  'husband wife cheated you, first find out?'
#  '53 products *seem* good true'
#  '17 tv movie moments taken straight real life, prove truth stranger fiction'
#  "would night italian dining go? – let's find"
#  "here's like compete beijing winter olympics according aussie athletes"
#  '23 product before-and-after photos probably loathe subjecting eyeballs seeing'
#  '55 awkward kinda awful early 2000s trends poised make comeback whether like'
#  'good, bad, ugly celebrity halloween costumes 10+ years ago totally forgot'
#  'i’d impressed make post without adding least one 42 products wish list'
#  '2021 update diversity, inclusion, belonging buzzfeed, inc.'
#  'eliza dushku spoke alleged sexual harassment faced "bull" co-star michael weatherly said would "smell" set'
#  'again, nick cannon plotting kids — time saweetie'
#  '24 celebrity couples mega famous, people know dated'
#  'sydney sweeney agreed cassie “chaotic” last night’s “euphoria” episode, revealed “really grossed out” filming hot tub scene'
#  '"sister, sister" first aired almost thirty years ago, here\'s cast looked like vs. look like today'
#  'directors must really love 17 pairs actors together since keep getting cast costars'
#  'machine gun kelly said filmed engagement megan fox iphone, evidence shows cannot true'
#  'answers determine "halloween kills" character'
#  '26 actors small roles movies, still managed totally steal show'
#  'unequal pay, unfulfillment, 17 reasons women leaving jobs tech'
#  'bush dog animal never heard desperately need life'
#  '27 cleaning products reviewers swear "only thing worked"'
#  '34 beauty products help freshen routine'
#  'australians explaining "bogan" rest world i\'m cackling'
#  'aussies sharing nostalgic things miss cities wish could turn back clock'
#  '50 scammers got exactly deserved end'
#  'dating behaviors green flags, red flags, full toxic?'
#  'taylor swift performed "all well" "snl" last night front lot famous friends'
#  'let\'s find "would rather" hero gyro'
#  '16 unhinged things celeb couples done name love'
#  '17 "dune" "star wars" similarities sci-fi fans instantly recognize'
#  "kourtney kardashian travis barker revealed they're engaged shared pictures proposal"
#  'woman gone super viral translating britney spears\' instagram captions "southern"'
#  'let\'s rank wildest moments "you" season 3 ton'
#  'people sharing silliest pettiest reasons relationships ended'
#  '"encanto" cast like first big role vs.'
#  '33 people explained said "see ya never" jobs great resignation'
#  'jessica alba shared relatable wisdom hardest part parent'
#  '15 stories formerly "creepy" men actually really, really important'
#  'david duchovny hilariously recalled brutal "full house" audition led nowhere'
#  "susan sarandon opened final conversation david bowie can't remember"
#  "halloween, scariest thing might results week's pop culture quiz"
#  'queen latifah spoke chris noth\'s sexual assault allegations firing "the equalizer"'
#  '32 skincare products reviewers highly recommend reason'
#  'well remember opening monologue "the lord rings: fellowship ring"?'
#  '15 "hamilton" "encanto" song mashups really hit hard'
#  '"i convinced otherwise": people sharing occasionally-questionable cooking opinions swear regardless'
#  'noodle pug internet chokehold “no bones day” content'
#  'here’s taylor swift fans made john mayer’s name trending “all well” short film premiered'
#  'rihanna perfectly replicated instagram post gunna halloween 2021 costume'
#  'every main cast members\' final words "the big bang theory"'
#  'true fans marvel cinematic universe score 10/13 quiz'
#  'bedtime routine compare everyone else?'
#  '38 products guaranteed tackle cleaning issues currently googling'
#  'ultimate bts song quiz: see rank bts army'
#  "kristen bell revealed dax shepard's kids sleep room"
#  'author "sex city" shared honest take show\'s un-feminist ending'
#  '13 tweets awe appreciation kristen stewart\'s princess diana "spencer"'
#  '29 practical products wanna keep bedside table'
#  'pete davidson colin jost bought ferry, talked "weekend update"'
#  '36 things anyone wants 2022 cleaner 2021'
#  'k-pop girl group twice answered 30 rapid fire questions learned much'
#  '19 delicious things buy small businesses'
#  'good luck making 75 terrifying things childhood millennial'
#  '39 products afters that’ll make say, "this work art"'
#  'joe jonas sophie turner reenacted old "kuwtk" moment kim khloé kardashian, watch'
#  '23 pictures abandoned places australia creep tf'
#  '21 bizarre "secret life american teenager" moments prove none us allowed watch high school'
#  'treated differently work disability?'
#  '18 hilarious "brooklyn nine-nine" cold opens fill void show left behind'
#  'james mcavoy secretly married girlfriend lisa liberati'
#  "someone never buy house, i'm super curious 25 problems would deal breakers"
#  'go way wash body parts shower liiiiiittle bit gross?'
#  'shia labeouf almost cast "call name" instead armie hammer'
#  'women pointing female issues get enough attention, lies detected'
#  "women sharing found underpaid work, i'm ready call hr"
#  '28 times carrie "sex city" made terrible decision absolutely learn'
#  'tbh, 30 red carpet looks would make pretty incredible halloween costumes'
#  "alyssa scott opened nick cannon's recent baby announcement month death 5-month-old son"
#  'shawn mendes posted snippet post-breakup music, camila cabello commented'
#  'plan meals day we’ll decide go spring break'
#  'fbi vs. dr. martin luther king jr.: life, activism, enemies, death civil rights icon explored'
#  '35 things reviewers found tiktok actually worth investment'
#  '35 things people cherish alone time'
#  '28 men politely turned nerve keep harassing someone'
#  '18 famous people flipped script completely changed career paths'
#  "chances are, birth control comes long list side effects — let's see many experienced"
#  '12 celeb engagement rings must taken money world purchase 8 affordable side'
#  '17 random unsettling facts make eye twitch'
#  'skeet ulrich admitted know "scream" comedy started shooting'
#  'jason sudeikis perfect reason go birth name daniel'
#  '24 roles actors literally embarrassed performance'
#  '"abbott elementary" new favorite sitcom — here\'s'
#  '26 inconsiderate people made home public'
#  'surgeons, librarians, people industries sharing things they’re tired repeating people place work'
#  'salma hayek lauren ridloff say marvel went extreme lengths maintain secrecy around "eternals"'
#  'eat fancy hotel buffet reveal "frozen" character'
#  "tried kraft's new mac & cheese flavors and, wow, yes, sign"
#  '16 reasons "the castle" beloved movie australian history'
#  "eat way alphabet we'll use high tech guesser accurately reveal hair color"
#  '15 types dirty talk straight men said ruined night'
#  "59 things might help fix life's big small problems"
#  'three cheers libraries like one, input new workstations juggling parents caregivers'
#  '31 photos portugal almost good actually'
#  'disney taking "different approach" "snow white" peter dinklage\'s impact'
#  '19 practical products level bathroom'
#  '17 tv characters clearly supposed big parts show disappeared first episode'
#  'oprah winfrey revealed who\'s going star "the color purple" musical film, great cast'
#  '28 celebrities legitimately good friends exes, despite public splits'
#  "no, shoving garlic nose clear sinuses — here's learned medical tiktok"
#  'tell us disney/pixar movie moment never fails make cry'
#  'basic bone test expose skipped high school anatomy']

# %%
clean_title_vals = title_df['clean_title'].values

title_wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      stopwords=stop_words,
                      min_font_size=8).generate(str(clean_title_vals))

plt.figure(figsize=(10, 8))
plt.imshow(title_wordcloud)
plt.title("Title WordCloud", size=20, fontweight='bold')
plt.axis('off')
plt.tight_layout()
plt.show();

# %% [markdown]
# Basically the 3 most popular words that BuzzFeed uses in their headlines are "thing", "people", and "make". We don't need to know the context in which they use them just yet, but let's see if these 3 popular words translate into what their top n-gram combinations are...

# %%
# n-gram visualizations

def get_ngrams(corpus, n=None):
    vec = CountVectorizer(ngram_range=(n, n), stop_words='english').fit(corpus)
    bow = vec.transform(corpus)
    sum_words = bow.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:15]

top_n_unigrams = get_ngrams(title_df['clean_title'], 1)
x, y = map(list, zip(*top_n_unigrams))
plt.figure(figsize=(10, 8))
sns.barplot(x=y, y=x)
plt.title("What are BuzzFeed's favourite words to use in its titles?", size=18, fontweight='bold')
plt.show();

# %%
top_n_bigrams = get_ngrams(title_df['clean_title'], 2)
x, y = map(list, zip(*top_n_bigrams))
plt.figure(figsize=(10, 8))
sns.barplot(x=y, y=x)
plt.title("Which pairs of words are most popular?", size=20, fontweight='bold')
plt.show();

# %% [markdown]
# These pairings of words are a bit funny based off the time that they were collected in. We can obviously pick out which sort of topics BuzzFeed was covering at the time of scraping: Taylor Swift was re-releasing another album and there was obviously some sort of Kanye drama going on.

# %% [markdown]
# We'll move on and start to do a bit of topic modeling with a cool library called `pyLDAvis`. First we'll process the text data a little bit more so the library functions can handle what we throw at it. We'll create a new function that will wrap all of our cleaning techniques into one:

# %%
def preprocess(df):
    corpus = []
    porter = PorterStemmer() # stemming
    for headline in title_df['clean_title']:
        words = [w for w in word_tokenize(headline) if (w not in stop_words)] # word tokenization & stopwords removal
        words = [porter.stem(w) for w in words if len(w)>2]
        words = [w.lower() for w in words] # a double check to lowercase everything
        # words = re.sub(r'[^\w\s]', '', ' '.join(words)) # remove punctuation
        
        corpus.append(words)
    return corpus

corpus = preprocess(title_df)

# %%
# create a Bag-of-Words model using gensim
dic = gensim.corpora.Dictionary(corpus)
bow_corpus = [dic.doc2bow(doc) for doc in corpus]

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus,
                                       num_topics=3,
                                       id2word=dic,
                                       passes=10,
                                       workers=2,
                                       random_state=2021)
lda_model.show_topics()
# Out:
# [(0,
#   '0.012*"product" + 0.009*"peopl" + 0.009*"love" + 0.008*"make" + 0.006*"\'ll" + 0.006*"share" + 0.006*"movi" + 0.005*"thing" + 0.005*"want" + 0.005*"day"'),
#  (1,
#   '0.012*"peopl" + 0.010*"time" + 0.008*"share" + 0.005*"thing" + 0.005*"prove" + 0.005*"stori" + 0.005*"celeb" + 0.005*"first" + 0.005*"women" + 0.005*"life"'),
#  (2,
#   '0.012*"thing" + 0.010*"product" + 0.007*"peopl" + 0.007*"like" + 0.006*"show" + 0.006*"make" + 0.006*"share" + 0.005*"actual" + 0.005*"film" + 0.004*"new"')]

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)
vis = gensimvis.prepare(lda_model, bow_corpus, dic)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el36171404887912593447707758957"></div>
# <script type="text/javascript">
#
# var ldavis_el36171404887912593447707758957_data = {"mdsDat": {"x": [-0.10859639607870775, 0.03371962195360541, 0.0748767741251023], "y": [0.020097135319616728, -0.0895903854994769, 0.06949325017986022], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [36.20199502917678, 33.871624858464514, 29.926380112358707]}, "tinfo": {"Term": ["product", "love", "time", "make", "celeb", "name", "australian", "'ll", "film", "fan", "prove", "euphoria", "home", "work", "stori", "parent", "day", "way", "opinion", "actor", "ever", "costum", "buy", "moment", "show", "hate", "friend", "kardashian", "n't", "total", "money", "truth", "today", "nice", "celeb", "ruin", "career", "advic", "plan", "left", "guy", "award", "davidson", "pete", "dakota", "bt", "attack", "jennif", "fianc\u00e9", "child", "lie", "join", "armi", "end", "snow", "sister", "sexual", "bush", "boyfriend", "past", "time", "prove", "turn", "place", "citi", "stori", "year", "happen", "icon", "ever", "n't", "think", "disney", "way", "life", "first", "women", "never", "look", "peopl", "kristen", "share", "moment", "relationship", "famou", "know", "get", "say", "reveal", "thing", "said", "like", "best", "movi", "one", "need", "name", "euphoria", "australian", "parent", "beauti", "review", "fan", "hadid", "disabl", "cultur", "popular", "sydney", "sweeney", "subtl", "kourtney", "barker", "easi", "member", "import", "jacob", "singl", "normal", "student", "routin", "doctor", "defend", "elordi", "emili", "dream", "weird", "kardashian", "100", "skincar", "quit", "joke", "gross", "toxic", "show", "film", "friend", "actual", "thing", "new", "hous", "feel", "product", "live", "stop", "like", "video", "make", "tiktok", "charact", "job", "home", "said", "peopl", "share", "tell", "say", "moment", "know", "celebr", "movi", "realli", "get", "reveal", "opinion", "costum", "buy", "total", "togeth", "tom", "hear", "hate", "ugli", "appear", "decor", "follow", "respons", "space", "piec", "hard", "pain", "support", "shop", "british", "incred", "content", "refresh", "view", "guarante", "crime", "obsess", "swear", "kitchen", "pattinson", "love", "pay", "'ll", "next", "list", "millenni", "day", "find", "thought", "bad", "product", "want", "make", "actor", "read", "work", "cast", "help", "photo", "aussi", "movi", "food", "tweet", "peopl", "home", "one", "realli", "share", "reveal", "thing", "would", "tell", "like", "use", "way"], "Freq": [55.0, 27.0, 34.0, 36.0, 15.0, 11.0, 12.0, 21.0, 20.0, 12.0, 18.0, 9.0, 19.0, 17.0, 18.0, 9.0, 18.0, 19.0, 7.0, 15.0, 18.0, 6.0, 6.0, 22.0, 25.0, 6.0, 13.0, 10.0, 16.0, 5.0, 5.56563986840998, 4.8297341050210445, 4.816513208975976, 5.490932254867229, 14.353137329383536, 4.068401643933086, 4.066997513366459, 4.060799603704846, 4.047080327983352, 5.378479464827265, 4.032542642826655, 4.665858533303882, 3.3062261044493537, 3.3061334291650417, 3.3041612457765894, 3.303658865728179, 3.3016033412567123, 3.2970495844808068, 3.2954507691442587, 3.287590704923007, 3.2799096573480697, 3.264263869151615, 3.214881943915272, 3.8292294038984256, 3.1856435584435037, 2.5432594914056494, 2.543089308914134, 2.543031303520356, 2.542937794825214, 2.542759611589729, 27.71967091692692, 14.711326636520704, 8.001568046009066, 5.5826447829882335, 3.7540400788958506, 14.696395914816511, 12.366735285440395, 7.799524591821643, 7.098839436843247, 13.027234036917923, 11.95553571567677, 9.922464665431571, 7.288562412046488, 12.72595802200694, 13.444602180281938, 14.086121833606768, 13.637344102876293, 10.916877133385837, 13.19978341519089, 35.41390905175484, 7.128575535262777, 23.875652137801094, 12.868904647593201, 7.05757093272052, 7.879796056066435, 11.759993532693134, 12.09843700371387, 11.594344796093758, 12.599935636830576, 15.373909581802256, 9.846374923368108, 11.981115427604207, 8.03305630735789, 9.349115351097845, 8.448832302672, 8.051998068705398, 10.65511559127147, 9.137905622399902, 11.125982698372967, 8.901817691676, 4.723195561874028, 4.704703636485641, 10.741401054179748, 3.9984790807095876 ...

# %%
def show_wordcloud(data):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stop_words,
        max_words=100,
        max_font_size=30,
        scale=3,
        random_state=42
    )
    wordcloud = wordcloud.generate(str(data))
    
    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    plt.imshow(wordcloud)
    plt.title("WordCloud based off LDA", size=28, fontweight='bold')
    plt.show();
    
show_wordcloud(corpus)

# %% [markdown]
# Moving on to use the TextBlob library to calculate the polarity and sentiment of the headlines.

# %%
from textblob import TextBlob

# %%
def polarity(text):
    # calculating polarity scores of our headlines
    # will give a score between -1.0 and 1.0
    return TextBlob(text).sentiment.polarity

title_df['polarity_score'] = title_df['title'].apply(lambda x: polarity(x))

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.histplot(title_df.polarity_score, kde=True, color=colors[2], edgecolor='black', ax=ax)
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
ax.set_title("Polarity Score of Titles", size=20, fontweight='bold')
ax.set_xlabel("Polarity Score")
plt.show();

# %%
title_df['polarity_score'].describe()
# Out:
# count    942.000000
# mean       0.113001
# std        0.301485
# min       -1.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.250000
# max        1.000000
# Name: polarity_score, dtype: float64

# %% [markdown]
# We can see that our mean polarity score is around 0.08 which is a very low score, meaning that our headlines, on average, are quite neutral and maybe even slightly more positive in their sentiment. BuzzFeed isn't generally a news outlet that gets too political, but we can also note that my period of collection of the headlines wasn't any significant point in time so there shouldn't be many polarizing topics unless BuzzFeed editors are feeling frisky. We'll have a better conclusion once we calculate the sentiments and visualize them.

# %% [markdown]
# So we've got polarity scores to quantitatively show what our headlines are like, but let's classify those scores as either positive, negative or neutral sentiment. We'll do this by creating a function that specifies a threshold, and if the scores are above, below, or equal to the threshold then we bin them into their corresponding category.

# %%
def sentiment(x):
    if x < 0:
        return 'negative'
    elif x == 0:
        return 'neutral'
    else:
        return 'positive'
    
title_df['sentiment'] = title_df['polarity_score'].apply(lambda x: sentiment(x))

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(title_df.sentiment.value_counts().index,
            title_df.sentiment.value_counts(), edgecolor='black')
ax.set_title("Title Sentiment Label Count based on Polarity Score", size=20, fontweight='bold')
ax.set_xlabel("Sentiment Label")
ax.set_ylabel("Count")
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
plt.tight_layout()
plt.show();

# %%
pct_sent = round((title_df.sentiment.value_counts() / (len(title_df)))*100, 2)
print(pct_sent)
# Out:
# positive    49.04
# neutral     32.70
# negative    18.26
# Name: sentiment, dtype: float64

# %% [markdown]
# Let's take a look at a few headlines from each sentiment category...

# %%
pos_headlines = title_df[title_df['sentiment'] == 'positive']['title']
print(pos_headlines.sample(3).tolist())
# Out:
# ["people look down on these things because women like them, and it's honestly so messed up", '15 things from shop buzzfeed that’ll make fun additions to your home', 'charisma carpenter issued a new statement in support of ray carter and said joss whedon was a "tyrannical narcissistic boss"']

# %%
neu_headlines = title_df[title_df['sentiment'] == 'neutral']['title']
print(neu_headlines.sample(3).tolist())
# Out:
# ["38 products guaranteed to tackle the cleaning issues you're currently googling", 'sebastian stan revealed he — wait for it — stashed steel balls in his pants to get into character for "pam & tommy"', '"make his pockets hurt" — this woman\'s take on why women shouldn\'t have to pay 50/50 on dates actually makes a lot of sense']

# %%
neg_headlines = title_df[title_df['sentiment'] == 'negative']['title']
print(neg_headlines.sample(3).tolist())
# Out:
# ['britney spears walked back her comments about jamie lynn being “scum,” and added that she was just “obviously hurt” by her', 'carole baskin of "tiger king" revealed what she thinks happened to her missing husband in a reddit ama', 'telling you not to discuss your pay with coworkers and 18 other red flags in the workplace']

# %% [markdown]
# We see some interesting headlines when we print out the results. Some even don't make sense being in the category that they're in. This could be due to the fact that some sentiment analysis techniques/libraries aren't great at detecting negative sentiments. One library that works pretty well at detecting negative sentiments is the VADER library. We can import it via `nltk` and work from there.

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

def vader_score(sent):
    ss = sia.polarity_scores(sent)
    
    return np.argmax(list(ss.values())[::-1])

title_df['polarity'] = title_df['title'].apply(lambda x: vader_score(x))
polarity = title_df['polarity'].replace({0:'neg', 2:'neu', 3:'pos'})
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jordansamek/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(polarity.value_counts().index,
            polarity.value_counts(), edgecolor='black')
ax.set_title("Sentiment Label (VADER calculation)", size=20, fontweight='bold')
ax.set_xlabel("VADER Sentiment Label")
ax.set_ylabel("Sentiment Count")
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
plt.tight_layout()
plt.show();

# %% [markdown]
# Wow! That's a massive shift in sentiments from our first run at it. Things that were probably classified as "borderline" negative or positive sentiments have now most likely shifted to neutral. We can probably guess now the titles that are in the negative & positive sentiment classes have scores that show they're close to the far ends of either spectrum.

# %%
title_df['polarity'].value_counts()
# Out:
# 2    853
# 0     82
# 3      6
# 1      1
# Name: polarity, dtype: int64

# %%
title_df['polarity'].describe()
# Out:
# count    942.000000
# mean       1.831210
# std        0.572262
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        3.000000
# Name: polarity, dtype: float64

# %%
def vader_sentiment(score):
    emotion = ""
    if score == 2.0:
        return "neutral"
    elif score == 3.0:
        return "positive"
    else:
        return "negative"

# %%
title_df['vader_sentiment'] = title_df['polarity'].apply(lambda x: vader_sentiment(x))
title_df['vader_sentiment'].value_counts()
# Out:
# neutral     853
# negative     83
# positive      6
# Name: vader_sentiment, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(title_df['vader_sentiment'].value_counts().index,
            title_df['vader_sentiment'].value_counts(), edgecolor='black')
ax.set_title("Sentiment Label (VADER calculation)", size=20, fontweight='bold')
ax.set_xlabel("VADER Sentiment Label")
ax.set_ylabel("Sentiment Count")
ax.grid(color='black', linestyle=':', axis='y', zorder=0, dashes=(6, 6))
plt.show();

# %% [markdown]
# Visualize NER with SpaCy

# %%
# hide
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 30.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.62.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.27.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (21.3)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: setuptools in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (59.8.0)
# Requirement already satisfied: jinja2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: zipp>=0.5 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.3->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.26.8)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jordansamek/opt/miniconda3/envs/baseline_env/lib/python3.7/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.1.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
# from IPython.core.display import display, HTML

nlp = spacy.load('en_core_web_sm')

for _ in range(4):
    rand_title = np.random.randint(0, 381)
    text = title_df['title'][rand_title]
    doc = nlp(text)
    displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">what money advice have you gotten from boomers that doesn't apply
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ?</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of rihanna and a$ap rocky's cutest couple fashion moments</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">here's how
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eric
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  nam would rank his songs</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">dakota johnson revealed that, on the set of “the social network”, andrew garfield was so nice, but jesse eisenberg ignored her existence</div></span>

# %% [markdown]
# I've run the above code multiple times and it seems like the visualizer doesn't pick up on some basic names. For now we'll move along. What we can do that might be useful is to apply NER on our headlines and then store the entity types.

# %%
from collections import Counter

def ner_types(text):
    doc = nlp(text)
    return [X.label_ for X in doc.ents]

ent = title_df['title'].apply(lambda x: ner_types(x))
ent = [x for sub in ent for x in sub]

counter = Counter(ent)
count = counter.most_common()

fig, ax = plt.subplots(figsize=(10, 8))
x, y = map(list, zip(*count))
sns.barplot(x=y, y=x, edgecolor='black')
ax.set_title("Count of NER Labels", size=20, fontweight='bold')
ax.set_xlabel("Label Count")
ax.set_ylabel("NER Label Type")
plt.tight_layout()
plt.show();

# %% [markdown]
# After the NER graph, I think it's clear even from our own observations that BuzzFeed loves numbers in their headlines.

# %%
title_df.head()
# Out:
#                                                title  title_len  \
# 0  rauw alejandro celebrated valentine's day with...        103
# 1      36 pieces of trivia i didn't believe at first         45
# 2  calling all video game lovers, tell us your fa...         73
# 3  14 facts that went over your head in "how to g...         66
# 4  36 wild secrets people are keeping from their ...         97
#
#                                          clean_title  polarity_score  \
# 0  rauw alejandro celebrated valentine's day "mus...            0.35
# 1                     36 pieces trivia believe first            0.25
# 2  calling video game lovers, tell us favourite c...           -0.40
# 3           14 facts went head "how get away murder"            0.00
# 4  36 wild secrets people keeping spouses "could ...            0.15
#
#   sentiment  polarity vader_sentiment
# 0  positive         2         neutral
# 1  positive         2         neutral
# 2  negative         0        negative
# 3   neutral         2         neutral
# 4  positive         2         neutral

# %% [markdown]
# Let's create a stripped down dataset for our deep learning models to come...

# %%
model_df = title_df[['clean_title']]
model_df.to_csv('../data/clean_titles.csv', index=False)
