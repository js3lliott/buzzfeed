# %%
import pandas as pd
import requests
import json

# %%
url = 'https://newsapi.org/v2/everything?sources=buzzfeed&apiKey=0934e20a24a64265b468e8c8b075f6ce'
response = requests.get(url).json()
content = json.dumps(response, indent=4, sort_keys=True)
print(content)
# Out:
# {
#     "articles": [
#         {
#             "author": "Genevieve Scarano",
#             "content": "This serum comes with a liquid serum base and a bottle of l-ascorbic acid powder that you need to mix together before application (more on that in my review below), and easy instructions on how to do\u2026 [+1660 chars]",
#             "description": "Gel eye masks, pore vacuums, hydrating serums, and more cult-favorite skincare products you'll want to buy again and again.View Entire Post \u203a",
#             "publishedAt": "2022-02-14T12:06:19Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "33 Skincare Products You'll Wanna Buy In Bulk Because The Reviews Are That Good",
#             "url": "https://www.buzzfeed.com/genevievescarano/skincare-products-wanna-buy-in-bulk",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/3/21/enhanced/cd8a5c5d04df/original-8425-1643922433-47.jpg?crop=1581:828;0,0%26downsize=1250:*"
#         },
#         {
#             "author": "Sumireko Tomita",
#             "content": "by Sumireko Tomita BuzzFeed News Reporter, Japan",
#             "description": "\u30a2\u30e1\u30ea\u30ab\u306e\u300c\u30de\u30f3\u30cf\u30c3\u30bf\u30f3\u30d7\u30ed\u30b8\u30a7\u30af\u30c8\u300d\u3068\u3044\u3046\u30af\u30e9\u30d5\u30c8\u30d3\u30fc\u30eb\u5e97\u306e\u30d3\u30fc\u30eb\u540d\u306b\u6279\u5224\u304c\u5bc4\u305b\u3089\u308c\u3066\u3044\u307e\u3059\u3002\u30d3\u30fc\u30eb\u306e\u540d\u524d\u306f\u300c\u5fc5\u8981\u60aa\u300d\u3084\u6838\u5b9f\u9a13\u306e\u540d\u524d\u306a\u3069\u304c\u4ed8\u3051\u3089\u308c\u3066\u3044\u307e\u3059\u3002",
#             "publishedAt": "2022-02-14T09:52:11Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "\u539f\u7206\u3092\u30c6\u30fc\u30de\u306b\u3057\u305f\u7c73\u56fd\u306e\u30d3\u30fc\u30eb\u306b\u6279\u5224\u3002\u540d\u524d\u306f\u300c\u9ed2\u3044\u96e8\u300d\u306b\u300c\u5fc5\u8981\u60aa\u300d\u3002\u5e83\u5cf6\u30fb\u9577\u5d0e\u306b\u6295\u4e0b\u306e\u539f\u7206\u306e\u30a4\u30e9\u30b9\u30c8\u3082\u7f36\u306b\u4f7f\u7528\u304b",
#             "url": "https://www.buzzfeed.com/jp/sumirekotomita/beer-atomic-bomb",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/14/9/enhanced/c912c55c7c11/original-1425-1644830100-4.jpg?crop=1134:594;0,109%26downsize=1250:*"
#         },
#         {
#             "author": "Allison Jiang",
#             "content": "You have the option to enter your waist, seat, thigh, knee, leg bottom, length, front rise, and back rise measurements either before or after you make your order. Your pants will be handmade exactly \u2026 [+639 chars]",
#             "description": "We've picked both faux and genuine leather options for every budget, so you can strut to your liking.View Entire Post \u203a",
#             "publishedAt": "2022-02-14T06:05:07Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "22 Pairs Of Leather Pants If Your Wardrobe Needs A Punk Pick-Me-Up",
#             "url": "https://www.buzzfeed.com/allisonjiang/leather-pants",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/10/15/enhanced/3c8363347d08/original-1621-1644507044-3.jpg?crop=1581:830;0,0%26downsize=1250:*"
#         },
#         {
#             "author": "Natasha Jokic",
#             "content": "Kevin C. Cox / Getty Images\r\nI know I shouldn't find it surprising that Blue Ivy isn't a baby anymore, but I do.",
#             "description": "Super-BEY.View Entire Post \u203a",
#             "publishedAt": "2022-02-14T04:06:18Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "
jpg?crop=1581:830;0,0%26downsize=1250:*"
#         },
#         {
#             "author": "Ajani Bazile",
#             "content": "HBO\r\nEpisode:\u00a0\u00a0Season 2, Episode 3 \"Ruminations: Big and Little Bullys and \"Season 2, Episode 5 \"Stand Still Like the Hummingbird\"",
#             "description": "\"The one thing I know is true is the longer you do drugs, the more you're gonna lose.\"View Entire Post \u203a",
#             "publishedAt": "2022-02-13T22:51:10Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "14 Times \"Euphoria\" Did A Great Job Of Depicting Addiction",
#             "url": "https://www.buzzfeed.com/ajanibazile/times-euphoria-depicted-addiction-well",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/9/22/enhanced/2910da2eafe2/original-1004-1644446170-14.jpg?crop=1200:628;0,0%26downsize=1250:*"
#         },
#         {
#             "author": "Ciera Velarde",
#             "content": "These detanglers from Wad-Free aren't recommended for use with bamboo, eucalyptus, or rayon sheets.\r\nWad-Free\u00a0is a small business that invented this laundry gadget to prevent sheets from tangling, tw\u2026 [+616 chars]",
#             "description": "All that's standing in your way of feeling like you're an adult is becoming the proud owner of a robot vacuum.View Entire Post \u203a",
#             "publishedAt": "2022-02-13T21:07:14Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "If You Want To Feel Just A *Little* Bit More Like A Grown-Up, Try Out These 45 Products",
#             "url": "https://www.buzzfeed.com/cieravelarde/things-that-make-you-feel-like-an-adult",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/4/15/enhanced/919ccd867310/original-10150-1643989219-10.jpg?crop=1246:653;0,89%26downsize=1250:*"
#         },
#         {
#             "author": "Hannah Marder",
#             "content": "ABC\r\nBullock has said of their friendship over a relationship: \"We just get to grow up together on parallel roads and tip our hats and meet for a dinner and try to work together. And the longer time \u2026 [+49 chars]",
#             "description": "I'm still mad Julianna Margulies and George Clooney never actually got together.View Entire Post \u203a",
#             "publishedAt": "2022-02-13T20:50:46Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "11 TV And Movie Couples Whose Chemistry Was So Good Because The Actors Literally Had Crushes On Each Other",
#             "url": "https://www.buzzfeed.com/hannahmarder/tv-and-movie-couples-where-the-actors-crushed-on-each-other",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/10/15/enhanced/eb78ff3bf8a9/original-1756-1644508552-19.jpg?crop=1581:830;0,0%26downsize=1250:*"
#         },
#         {
#             "author": "Emma Lord",
#             "content": "Each kit comes with a simple design, a cotton cloth, a bamboo embroidery hoop, a little scissor, colored threads, embroidery needles, and instructions, so you should be raring to go when it arrives! \u2026 [+889 chars]",
#             "description": "Humans are great, but a night alone with a good book, a chocolate mug cake, and a TikTok-famous showerhead is almost always better.View Entire Post \u203a",
#             "publishedAt": "2022-02-13T20:07:03Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "35 Things For People Who Cherish Their Alone Time",
#             "url": "https://www.buzzfeed.com/emmalord9/products-cherish-alone-time",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/9/16/enhanced/cba29e79595f/original-713-1644425860-13.jpg?crop=1581:830;0,0%26downsize=1250:*"
#         },
#         {
#             "author": "Angelica Martinez",
#             "content": "Here's how this quiz works: This quiz uses 13 multiple choice questions to analyze your preferences and decision-making habits. All you've got to do is tap on the image that best answers each prompt.\u2026 [+197 chars]",
#             "description": "C'mon, I know you're curious. \ud83e\udde0View Entire Post \u203a",
#             "publishedAt": "2022-02-13T19:36:33Z",
#             "source": {
#                 "id": "buzzfeed",
#                 "name": "Buzzfeed"
#             },
#             "title": "This In-Depth Personality Quiz Will Reveal Whether You're Right Or Left Brain Dominant",
#             "url": "https://www.buzzfeed.com/angelicaamartinez/right-left-brain-dominant-quiz",
#             "urlToImage": "https://img.buzzfeed.com/buzzfeed-static/static/2022-02/9/19/enhanced/cb3816aac5f2/original-566-1644435647-11.jpg?crop=1581:830;0,0%26downsize=1250:*"
#         }
#     ],
#     "status": "ok",
#     "totalResults": 995
# }

# %%
data = json.loads(content)['articles']

buzz_df = pd.DataFrame(data)
buzz_df.head()
# Out:
#               author                                            content  \
# 0  Genevieve Scarano  This serum comes with a liquid serum base and ...
# 1    Sumireko Tomita   by Sumireko Tomita BuzzFeed News Reporter, Japan
# 2      Allison Jiang  You have the option to enter your waist, seat,...
# 3      Natasha Jokic  Kevin C. Cox / Getty Images\r\nI know I should...
# 4       Andria Moore  @mickeyguyton / Via instagram.com"Look at God,...
#
#                                          description           publishedAt  \
# 0  Gel eye masks, pore vacuums, hydrating serums,...  2022-02-14T12:06:19Z
# 1  アメリカの「マンハッタンプロジェクト」というクラフトビール店のビール名に批判が寄せられていま...  2022-02-14T09:52:11Z
# 2  We've picked both faux and genuine leather opt...  2022-02-14T06:05:07Z
# 3                       Super-BEY.View Entire Post ›  2022-02-14T04:06:18Z
# 4         Have we learned nothing?View Entire Post ›  2022-02-14T03:36:43Z
#
#                                    source  \
# 0  {'id': 'buzzfeed', 'name': 'Buzzfeed'}
# 1  {'id': 'buzzfeed', 'name': 'Buzzfeed'}
# 2  {'id': 'buzzfeed', 'name': 'Buzzfeed'}
# 3  {'id': 'buzzfeed', 'name': 'Buzzfeed'}
# 4  {'id': 'buzzfeed', 'name': 'Buzzfeed'}
#
#                                                title  \
# 0  33 Skincare Products You'll Wanna Buy In Bulk ...
# 1  原爆をテーマにした米国のビールに批判。名前は「黒い雨」に「必要悪」。広島・長崎に投下の原爆の...
# 2  22 Pairs Of Leather Pants If Your Wardrobe Nee...
# 3  Jay-Z And Beyoncé Dancing To The Super Bowl Ha...
# 4  NBC Confused Mickey Guyton And Jhené Aiko's Na...
#
#                                                  url  \
# 0  https://www.buzzfeed.com/genevievescarano/skin...
# 1  https://www.buzzfeed.com/jp/sumirekotomita/bee...
# 2  https://www.buzzfeed.com/allisonjiang/leather-...
# 3  https://www.buzzfeed.com/natashajokic1/beyonce...
# 4  https://www.buzzfeed.com/andriamoore/mickey-gu...
#
#                                           urlToImage
# 0  https://img.buzzfeed.com/buzzfeed-static/stati...
# 1  https://img.buzzfeed.com/buzzfeed-static/stati...
# 2  https://img.buzzfeed.com/buzzfeed-static/stati...
# 3  https://img.buzzfeed.com/buzzfeed-static/stati...
# 4  https://img.buzzfeed.com/buzzfeed-static/stati...

# %%
buzz_df.drop(['author', 'publishedAt', 'source', 'url', 'urlToImage'], inplace=True, axis=1)

# %%
print(buzz_df.shape)
buzz_df.head()
# Out:
# (20, 3)
#                                              content  \
# 0  This serum comes with a liquid serum base and ...
# 1   by Sumireko Tomita BuzzFeed News Reporter, Japan
# 2  You have the option to enter your waist, seat,...
# 3  Kevin C. Cox / Getty Images\r\nI know I should...
# 4  @mickeyguyton / Via instagram.com"Look at God,...
#
#                                          description  \
# 0  Gel eye masks, pore vacuums, hydrating serums,...
# 1  アメリカの「マンハッタンプロジェクト」というクラフトビール店のビール名に批判が寄せられていま...
# 2  We've picked both faux and genuine leather opt...
# 3                       Super-BEY.View Entire Post ›
# 4         Have we learned nothing?View Entire Post ›
#
#                                                title
# 0  33 Skincare Products You'll Wanna Buy In Bulk ...
# 1  原爆をテーマにした米国のビールに批判。名前は「黒い雨」に「必要悪」。広島・長崎に投下の原爆の...
# 2  22 Pairs Of Leather Pants If Your Wardrobe Nee...
# 3  Jay-Z And Beyoncé Dancing To The Super Bowl Ha...
# 4  NBC Confused Mickey Guyton And Jhené Aiko's Na...

# %%
buzz_df.to_csv('buzz_df_day44.csv')

# %%
# !mv buzz_df_day44.csv ../data/
